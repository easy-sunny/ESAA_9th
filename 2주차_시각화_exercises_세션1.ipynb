# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73],
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}

# %%
mydata=pd.DataFrame(raw_data)

# %%
mydata
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
fig,ax= plt.subplots()
ax.scatter(mydata["preTestScore"],mydata["postTestScore"],s=mydata["age"])
ax.set(xlabel="preTestScore",ylabel="postTest score",title="scatter plot")
# Out:
# [Text(0.5, 0, 'preTestScore'),
#  Text(0, 0.5, 'postTest score'),
#  Text(0.5, 1.0, 'scatter plot')]

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
fig,ax= plt.subplots()
ax.scatter(mydata["preTestScore"],mydata["postTestScore"],s=mydata["postTestScore"]*4.5, c=mydata["female"])
ax.set(xlabel="preTestScore",ylabel="postTest score",title="scatter plot")
# Out:
# [Text(0.5, 0, 'preTestScore'),
#  Text(0, 0.5, 'postTest score'),
#  Text(0.5, 1.0, 'scatter plot')]

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
fig, ax = plt.subplots()
sns.boxplot(x="female", y="preTestScore",data=mydata)
# Out:
# <AxesSubplot:xlabel='female', ylabel='preTestScore'>

# %%
fig, ax = plt.subplots()
sns.boxplot(x="female", y="postTestScore",data=mydata)
# Out:
# <AxesSubplot:xlabel='female', ylabel='postTestScore'>
