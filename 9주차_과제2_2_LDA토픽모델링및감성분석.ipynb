# %% [markdown]
# # TEXT MINING for BEGINNER
# - 본 자료는 텍스트 마이닝을 활용한 연구 및 강의를 위한 목적으로 제작되었습니다.
# - 본 자료를 강의 목적으로 활용하고자 하시는 경우 꼭 아래 메일주소로 연락주세요.
# - 본 자료에 대한 허가되지 않은 배포를 금지합니다.
# - 강의, 저작권, 출판, 특허, 공동저자에 관련해서는 문의 바랍니다.
# - **Contact : ADMIN(admin@teanaps.com)**
#
# ---

# %% [markdown]
# ## 실전 텍스트 분석하기: LDA토픽모델링, 감성분석
# - Python을 활용해 텍스트 데이터를 분석하는 여러가지 방법에 대해 다룹니다.
#
# ---

# %% [markdown]
# ### 1. LDA토픽모델링: 단어를 문서에 포함된 주제단위로 군집화하기
#
# ---

# %% [markdown]
# #### 1.1. 샘플 데이터 불러오기
#
# ---

# %%
# 기사본문을 저장할 리스트를 생성합니다.
article_list = []

# 기사가 저장된 파일은 data 폴더 안에 저장되어 있습니다.
file_path = "/Users/ijiseon/Desktop/ESAA-OB/article_sample.txt"

# 기사가 저장된 파일을 불러옵니다.
f = open(file_path, encoding="utf-8")
for line in f:
    col = line.strip().split("\t")
    #group = col[0]
    #source = col[1]
    #datetime = col[2]
    #title = col[3]
    # 기사의 본문만 가져와 리스트에 저장합니다.
    content = col[4]
    article_list.append(content)
f.close()

print("총 기사 수 :", len(article_list))
# Out:
# 총 기사 수 : 100

# %%
print("기사샘플 :")
print(article_list[3][:1000])
# Out:
# 기사샘플 :
# 10년 역사 10대 뉴스로 정리(지디넷코리아=임유경 기자)2008년 9월 리먼 브라더스 파산으로 촉발된 금융위기가 전 세계를 뒤흔들었다. 세계 금융시스템이 붕괴 위기에 놓여 있던 이때, 인터넷 세상 한 켠에선 새로운 금융 시스템이 조용하게 작동을 시작했다. 10년 전 1월 3일 오후 6시 15분. 은행이나 정부의 개입이 필요 없는 개인 간 전자화폐 시스템 비트코인 네트워크의 첫 번째 블록이 탄생한 순간이다.이날 사토시 나카모토라는 가명의 인물은 앞서 공개한 논문을 통해 제시한 아이디어를 약 한달만에 구현하는 데 성공했다. 기념비적인 첫 번째 블록에는 "재무장관, 은행에 두 번째 구제금융 제공 임박”이라는 문구를 새겼다. 이날 영국 일간지 <타임스>의 1면 헤드라인으로, 비트코인 네트워크가 기존 금융 시스템에 대안적인 성격을 띤다는 정체성을 분명하게 드러냈다.이후 비트코인은 굴곡진 10년의 세월을 보냈다. 2011년 초까지 1달러의 가치도 인정 받지 못했다. 비트코인에 대한 관심도 암호학 커뮤니티 내 개발자들이 재미로 채굴(트랜잭션을 블록단위로 묶어 처리하는 작업)하고 비트코인을 받는 수준에 그쳤다. 이후 관심을 늘었지만 투기기 불법적인 요소 결합돼 버블이니 검은 돈이니 하는 오명을 얻기도 했다.2009년 1월 3일 비트코인 첫 번째 블록인 제네시스 블록이 생성됐다.여전비 비트코인은 실험대 위에 있다. 가격이 출렁일 때마다 "비트코인은 죽었다"는 제목의 기사가 쏟아져 나온다. 지난해 언론에서 내린 사망선고는 거의 100번에 이른다. (☞관련링크)분명한 것은 비트코인의 잠재력을 믿는 사람들이 늘어나고 있다는 점이다. 이제 전 세계 모든 주요 기업들이 비트코인 기반 기술인 블록체인의 혁신성에 주목하고 기존 비즈니스에 적용하기 위해 연구에 나섰다.비트코인 맥시멀리스트로 알려진 지미 송은 최근 자신의 블로그에 비트코인이 가진 특성 중 탈중앙성(정부나 은행의 개입이 없는 상태)에 주목해야 한다고 강조하며 "기업가들은 비트코인 내에서 자신의 돈과 노력을 가지고 어떤 혁신을

# %% [markdown]
# #### 1.2. 기사 문장을 형태소 단위로 분리하기
#
# ---

# %%
# %env JAVA_HOME=/usr/local/opt/openjdk@11/libexec/openjdk.jdk/Contents/Home
# Out:
# env: JAVA_HOME=/usr/local/opt/openjdk@11/libexec/openjdk.jdk/Contents/Home

# %%
# 꼬꼬마 형태소 분석기를 불러옵니다.
from konlpy.tag import Kkma
kkma = Kkma()

text = "꼬꼬마 형태소 분석기를 불러옵니다."
print(kkma.pos(text))
# Out:
# [('꼬꼬마', 'NNG'), ('형태소', 'NNG'), ('분석기', 'NNG'), ('를', 'JKO'), ('불러오', 'VV'), ('ㅂ니다', 'EFN'), ('.', 'SF')]

# %%
# 형태소분석 후 기사단위의 형태소 리스트를 저장할 리스트를 생성합니다.
tag_sentence_list = []

# 불용어를 리스트를 정의합니다.
stop_list = ["카페", "카페규정"]

# 형태소 중 꼭 포함해야하는 형태소 태그를 리스트로 생성합니다.
pos_list = ["NNG", "NNP"]

now = 0
for article in article_list:
    now += 1
    print(now, end="\r")
    sentence_list = kkma.sentences(article)
    tag_sentence = []
    for sentence in sentence_list:
        tag_list = kkma.pos(sentence)
        for word, pos in tag_list:
            if pos in pos_list and word not in stop_list and len(word) > 1:
                tag_sentence.append(word)
    tag_sentence_list.append(tag_sentence)
# Out:
# 100

# %% [markdown]
# #### 1.3. LDA토픽모델링 수행하기
#
# ---

# %%
# 텍스트 분석을 위한 다양한 기능을 제공하는 gensim 패키지를 설치합니다.

# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=0.18.1 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from gensim) (5.2.1)

# %%
# gensim 패키지를 불러옵니다.
import gensim
from gensim import corpora

# LDA토픽모델링 수행중에는 진행중인 상황에 대한 로그가 출력됩니다.
# 아래 7~9번째 줄을 주석처리하면 로그를 확인할 수 있습니다.
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
# 추출할 토픽의 개수를 지정합니다.
my_num_topic = 3

# 각 토픽에 포함할 키워드(단어) 개수를 지정합니다.
my_num_keyword = 10

# %%
# LDA토픽모델링을 수행합니다.

dictionary = corpora.Dictionary(tag_sentence_list)
corpus = [dictionary.doc2bow(text) for text in tag_sentence_list]

# %%
dictionary

# %%
corpus
# Out:
# [[(0, 1),
#   (1, 1),
#   (2, 1),
#   (3, 2),
#   (4, 3),
#   (5, 1),
#   (6, 1),
#   (7, 2),
#   (8, 8),
#   (9, 2),
#   (10, 1),
#   (11, 3),
#   (12, 2),
#   (13, 6),
#   (14, 9),
#   (15, 1),
#   (16, 1),
#   (17, 2),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 2),
#   (25, 1),
#   (26, 3),
#   (27, 5),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 2),
#   (35, 1),
#   (36, 1),
#   (37, 3),
#   (38, 1),
#   (39, 1),
#   (40, 5),
#   (41, 3),
#   (42, 1),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 1),
#   (47, 1),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (51, 2),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 2),
#   (56, 1),
#   (57, 1),
#   (58, 3),
#   (59, 1),
#   (60, 3),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 2),
#   (65, 4),
#   (66, 1),
#   (67, 1),
#   (68, 14),
#   (69, 1),
#   (70, 2),
#   (71, 1),
#   (72, 2),
#   (73, 1),
#   (74, 1),
#   (75, 1),
#   (76, 2),
#   (77, 1),
#   (78, 1),
#   (79, 2),
#   (80, 2),
#   (81, 1),
#   (82, 1),
#   (83, 1),
#   (84, 1),
#   (85, 2),
#   (86, 1),
#   (87, 5),
#   (88, 1),
#   (89, 1),
#   (90, 1),
#   (91, 11),
#   (92, 1),
#   (93, 1),
#   (94, 1),
#   (95, 2),
#   (96, 2),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 4),
#   (101, 1),
#   (102, 2),
#   (103, 1),
#   (104, 1),
#   (105, 1),
#   (106, 1),
#   (107, 1),
#   (108, 1),
#   (109, 1),
#   (110, 1),
#   (111, 1),
#   (112, 1),
#   (113, 1),
#   (114, 2),
#   (115, 2),
#   (116, 1),
#   (117, 2),
#   (118, 1),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 1),
#   (123, 1),
#   (124, 2),
#   (125, 1),
#   (126, 1),
#   (127, 3),
#   (128, 2),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 1),
#   (133, 1),
#   (134, 1),
#   (135, 1),
#   (136, 1),
#   (137, 2),
#   (138, 1),
#   (139, 1),
#   (140, 1),
#   (141, 1),
#   (142, 1),
#   (143, 1),
#   (144, 1),
#   (145, 1),
#   (146, 1),
#   (147, 3),
#   (148, 1),
#   (149, 2),
#   (150, 1),
#   (151, 1),
#   (152, 1),
#   (153, 1),
#   (154, 1),
#   (155, 1),
#   (156, 1),
#   (157, 1),
#   (158, 1),
#   (159, 2),
#   (160, 1),
#   (161, 2),
#   (162, 1),
#   (163, 2),
#   (164, 1),
#   (165, 2),
#   (166, 1),
#   (167, 1),
#   (168, 12),
#   (169, 1),
#   (170, 2)],
#  [(0, 1),
#   (3, 1),
#   (27, 3),
#   (32, 1),
#   (34, 2),
#   (47, 1),
#   (52, 2),
#   (54, 1),
#   (65, 2),
#   (68, 11),
#   (85, 2),
#   (88, 1),
#   (91, 1),
#   (92, 2),
#   (113, 1),
#   (114, 5),
#   (118, 1),
#   (134, 2),
#   (148, 2),
#   (158, 1),
#   (163, 2),
#   (168, 2),
#   (171, 1),
#   (172, 1),
#   (173, 1),
#   (174, 1),
#   (175, 1),
#   (176, 3),
#   (177, 1),
#   (178, 1),
#   (179, 1),
#   (180, 6),
#   (181, 2),
#   (182, 1),
#   (183, 1),
#   (184, 1),
#   (185, 1),
#   (186, 1),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 2),
#   (191, 2),
#   (192, 1),
#   (193, 1),
#   (194, 2),
#   (195, 1),
#   (196, 1),
#   (197, 2),
#   (198, 3),
#   (199, 2),
#   (200, 1),
#   (201, 1),
#   (202, 1),
#   (203, 1),
#   (204, 1),
#   (205, 2),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 2),
#   (212, 2),
#   (213, 2),
#   (214, 1),
#   (215, 1),
#   (216, 2),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 1),
#   (221, 1),
#   (222, 1),
#   (223, 1),
#   (224, 1),
#   (225, 1),
#   (226, 1),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 1),
#   (234, 1),
#   (235, 1),
#   (236, 1),
#   (237, 1),
#   (238, 1),
#   (239, 1),
#   (240, 2),
#   (241, 1),
#   (242, 1),
#   (243, 1),
#   (244, 1),
#   (245, 1),
#   (246, 1),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 6),
#   (251, 3),
#   (252, 1),
#   (253, 2),
#   (254, 1),
#   (255, 1),
#   (256, 1),
#   (257, 2),
#   (258, 1),
#   (259, 1),
#   (260, 4),
#   (261, 1),
#   (262, 1)],
#  [(3, 2),
#   (13, 1),
#   (19, 1),
#   (27, 4),
#   (30, 1),
#   (34, 2),
#   (65, 2),
#   (68, 20),
#   (71, 3),
#   (72, 2),
#   (74, 1),
#   (81, 1),
#   (87, 1),
#   (88, 1),
#   (91, 11),
#   (92, 3),
#   (111, 1),
#   (116, 6),
#   (129, 1),
#   (137, 3),
#   (142, 1),
#   (146, 1),
#   (148, 2),
#   (157, 3),
#   (160, 1),
#   (163, 4),
#   (168, 12),
#   (171, 1),
#   (172, 1),
#   (173, 2),
#   (176, 3),
#   (179, 1),
#   (181, 2),
#   (182, 1),
#   (186, 1),
#   (187, 1),
#   (190, 15),
#   (192, 1),
#   (193, 1),
#   (196, 1),
#   (200, 1),
#   (201, 1),
#   (205, 4),
#   (210, 1),
#   (211, 2),
#   (213, 1),
#   (227, 5),
#   (229, 1),
#   (233, 1),
#   (236, 1),
#   (237, 2),
#   (243, 1),
#   (251, 1),
#   (263, 7),
#   (264, 1),
#   (265, 1),
#   (266, 1),
#   (267, 2),
#   (268, 1),
#   (269, 1),
#   (270, 1),
#   (271, 1),
#   (272, 1),
#   (273, 1),
#   (274, 1),
#   (275, 1),
#   (276, 1),
#   (277, 1),
#   (278, 2),
#   (279, 2),
#   (280, 1),
#   (281, 1),
#   (282, 1),
#   (283, 1),
#   (284, 4),
#   (285, 1),
#   (286, 1),
#   (287, 1),
#   (288, 1),
#   (289, 1),
#   (290, 2),
#   (291, 1),
#   (292, 2),
#   (293, 1),
#   (294, 1),
#   (295, 1),
#   (296, 1),
#   (297, 1),
#   (298, 1),
#   (299, 2),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 2),
#   (304, 4),
#   (305, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 1),
#   (312, 8),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 2),
#   (320, 1),
#   (321, 1),
#   (322, 1),
#   (323, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 2),
#   (328, 1),
#   (329, 1),
#   (330, 2),
#   (331, 1),
#   (332, 1),
#   (333, 3),
#   (334, 1),
#   (335, 1),
#   (336, 1),
#   (337, 2),
#   (338, 1),
#   (339, 1),
#   (340, 1),
#   (341, 2),
#   (342, 8),
#   (343, 1),
#   (344, 1),
#   (345, 1),
#   (346, 1),
#   (347, 1),
#   (348, 1),
#   (349, 1),
#   (350, 4),
#   (351, 5),
#   (352, 1),
#   (353, 3),
#   (354, 1),
#   (355, 1),
#   (356, 1),
#   (357, 1),
#   (358, 1),
#   (359, 2)],
#  [(0, 7),
#   (3, 3),
#   (7, 1),
#   (8, 7),
#   (9, 6),
#   (26, 1),
#   (27, 5),
#   (32, 2),
#   (33, 1),
#   (34, 2),
#   (40, 6),
#   (46, 1),
#   (65, 17),
#   (68, 48),
#   (70, 1),
#   (73, 1),
#   (91, 5),
#   (110, 1),
#   (114, 3),
#   (115, 1),
#   (116, 2),
#   (124, 3),
#   (127, 2),
#   (129, 1),
#   (130, 1),
#   (136, 1),
#   (137, 1),
#   (146, 4),
#   (147, 1),
#   (148, 7),
#   (153, 1),
#   (155, 5),
#   (159, 2),
#   (161, 1),
#   (163, 2),
#   (166, 2),
#   (168, 7),
#   (186, 1),
#   (188, 3),
#   (194, 1),
#   (197, 1),
#   (205, 1),
#   (209, 1),
#   (228, 1),
#   (231, 2),
#   (241, 1),
#   (242, 1),
#   (245, 1),
#   (251, 1),
#   (263, 1),
#   (268, 2),
#   (273, 2),
#   (274, 1),
#   (275, 1),
#   (279, 3),
#   (291, 1),
#   (297, 3),
#   (302, 2),
#   (308, 4),
#   (314, 1),
#   (322, 1),
#   (323, 1),
#   (328, 1),
#   (331, 2),
#   (336, 1),
#   (343, 1),
#   (351, 2),
#   (355, 2),
#   (357, 2),
#   (360, 1),
#   (361, 2),
#   (362, 1),
#   (363, 1),
#   (364, 1),
#   (365, 2),
#   (366, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1),
#   (370, 1),
#   (371, 1),
#   (372, 2),
#   (373, 2),
#   (374, 1),
#   (375, 1),
#   (376, 1),
#   (377, 1),
#   (378, 1),
#   (379, 1),
#   (380, 1),
#   (381, 1),
#   (382, 1),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 1),
#   (387, 2),
#   (388, 1),
#   (389, 1),
#   (390, 4),
#   (391, 1),
#   (392, 1),
#   (393, 1),
#   (394, 2),
#   (395, 1),
#   (396, 1),
#   (397, 1),
#   (398, 1),
#   (399, 1),
#   (400, 2),
#   (401, 1),
#   (402, 2),
#   (403, 1),
#   (404, 2),
#   (405, 1),
#   (406, 2),
#   (407, 1),
#   (408, 7),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 2),
#   (413, 1),
#   (414, 1),
#   (415, 1),
#   (416, 1),
#   (417, 1),
#   (418, 1),
#   (419, 1),
#   (420, 1),
#   (421, 2),
#   (422, 1),
#   (423, 1),
#   (424, 1),
#   (425, 6),
#   (426, 1),
#   (427, 1),
#   (428, 1),
#   (429, 4),
#   (430, 1),
#   (431, 1),
#   (432, 2),
#   (433, 1),
#   (434, 1),
#   (435, 1),
#   (436, 1),
#   (437, 1),
#   (438, 1),
#   (439, 1),
#   (440, 1),
#   (441, 5),
#   (442, 1),
#   (443, 1),
#   (444, 4),
#   (445, 1),
#   (446, 4),
#   (447, 5),
#   (448, 4),
#   (449, 1),
#   (450, 2),
#   (451, 1),
#   (452, 1),
#   (453, 1),
#   (454, 1),
#   (455, 1),
#   (456, 2),
#   (457, 1),
#   (458, 1),
#   (459, 1),
#   (460, 1),
#   (461, 1),
#   (462, 1),
#   (463, 1),
#   (464, 2),
#   (465, 1),
#   (466, 1),
#   (467, 1),
#   (468, 1),
#   (469, 1),
#   (470, 1),
#   (471, 2),
#   (472, 2),
#   (473, 1),
#   (474, 3),
#   (475, 1),
#   (476, 3),
#   (477, 1),
#   (478, 1),
#   (479, 7),
#   (480, 2),
#   (481, 1),
#   (482, 1),
#   (483, 1),
#   (484, 1),
#   (485, 1),
#   (486, 1),
#   (487, 3),
#   (488, 1),
#   (489, 2),
#   (490, 1),
#   (491, 1),
#   (492, 1),
#   (493, 1),
#   (494, 1),
#   (495, 1),
#   (496, 1),
#   (497, 2),
#   (498, 1),
#   (499, 1),
#   (500, 1),
#   (501, 1),
#   (502, 1),
#   (503, 2),
#   (504, 1),
#   (505, 1),
#   (506, 1),
#   (507, 3),
#   (508, 2),
#   (509, 1),
#   (510, 1),
#   (511, 2),
#   (512, 1),
#   (513, 1),
#   (514, 1),
#   (515, 1),
#   (516, 1),
#   (517, 1),
#   (518, 1),
#   (519, 1),
#   (520, 1),
#   (521, 7),
#   (522, 1),
#   (523, 1),
#   (524, 2),
#   (525, 2),
#   (526, 2),
#   (527, 2),
#   (528, 2),
#   (529, 2),
#   (530, 1),
#   (531, 1),
#   (532, 1),
#   (533, 2),
#   (534, 1),
#   (535, 2),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 2),
#   (540, 2),
#   (541, 1),
#   (542, 1),
#   (543, 5),
#   (544, 1),
#   (545, 1),
#   (546, 1),
#   (547, 1),
#   (548, 1),
#   (549, 1),
#   (550, 1),
#   (551, 1),
#   (552, 1),
#   (553, 2)],
#  [(3, 4),
#   (9, 3),
#   (27, 5),
#   (34, 3),
#   (43, 5),
#   (51, 1),
#   (65, 1),
#   (68, 9),
#   (87, 1),
#   (91, 2),
#   (114, 2),
#   (116, 1),
#   (142, 1),
#   (148, 2),
#   (152, 1),
#   (168, 2),
#   (170, 1),
#   (174, 1),
#   (176, 2),
#   (183, 2),
#   (199, 2),
#   (213, 2),
#   (231, 1),
#   (247, 1),
#   (251, 1),
#   (259, 1),
#   (273, 1),
#   (290, 1),
#   (297, 1),
#   (304, 1),
#   (305, 1),
#   (307, 1),
#   (330, 1),
#   (341, 1),
#   (349, 2),
#   (355, 2),
#   (357, 1),
#   (359, 1),
#   (363, 1),
#   (367, 1),
#   (370, 1),
#   (386, 3),
#   (418, 1),
#   (425, 1),
#   (432, 2),
#   (437, 2),
#   (447, 3),
#   (456, 1),
#   (471, 1),
#   (474, 1),
#   (479, 2),
#   (511, 1),
#   (521, 1),
#   (551, 3),
#   (554, 1),
#   (555, 1),
#   (556, 1),
#   (557, 1),
#   (558, 1),
#   (559, 1),
#   (560, 1),
#   (561, 1),
#   (562, 4),
#   (563, 1),
#   (564, 1),
#   (565, 1),
#   (566, 1),
#   (567, 1),
#   (568, 1),
#   (569, 2),
#   (570, 1),
#   (571, 1),
#   (572, 2),
#   (573, 1),
#   (574, 1),
#   (575, 1),
#   (576, 1),
#   (577, 2),
#   (578, 4),
#   (579, 1),
#   (580, 1),
#   (581, 1),
#   (582, 1),
#   (583, 1),
#   (584, 1),
#   (585, 1),
#   (586, 1),
#   (587, 1),
#   (588, 4),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 1),
#   (593, 2),
#   (594, 1),
#   (595, 1),
#   (596, 1),
#   (597, 1),
#   (598, 1),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 3),
#   (604, 1),
#   (605, 1),
#   (606, 1),
#   (607, 1),
#   (608, 2),
#   (609, 1),
#   (610, 1),
#   (611, 1),
#   (612, 2),
#   (613, 1),
#   (614, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1),
#   (618, 5),
#   (619, 2),
#   (620, 1),
#   (621, 2),
#   (622, 1),
#   (623, 1),
#   (624, 1),
#   (625, 1),
#   (626, 1)],
#  [(0, 3),
#   (2, 2),
#   (8, 2),
#   (22, 1),
#   (27, 2),
#   (31, 1),
#   (35, 2),
#   (40, 2),
#   (41, 1),
#   (43, 1),
#   (52, 1),
#   (68, 16),
#   (71, 2),
#   (74, 2),
#   (86, 1),
#   (87, 5),
#   (91, 6),
#   (92, 2),
#   (109, 1),
#   (114, 2),
#   (115, 1),
#   (126, 1),
#   (127, 1),
#   (129, 1),
#   (168, 6),
#   (171, 2),
#   (176, 3),
#   (202, 1),
#   (222, 1),
#   (225, 1),
#   (231, 1),
#   (232, 1),
#   (241, 1),
#   (242, 1),
#   (247, 1),
#   (269, 1),
#   (270, 1),
#   (275, 1),
#   (300, 1),
#   (305, 3),
#   (308, 2),
#   (314, 1),
#   (342, 2),
#   (353, 1),
#   (367, 1),
#   (378, 1),
#   (380, 1),
#   (387, 1),
#   (427, 1),
#   (456, 2),
#   (467, 1),
#   (476, 1),
#   (518, 1),
#   (520, 2),
#   (523, 1),
#   (534, 1),
#   (538, 1),
#   (580, 1),
#   (619, 1),
#   (627, 1),
#   (628, 1),
#   (629, 1),
#   (630, 1),
#   (631, 1),
#   (632, 1),
#   (633, 1),
#   (634, 1),
#   (635, 1),
#   (636, 3),
#   (637, 1),
#   (638, 1),
#   (639, 1),
#   (640, 1),
#   (641, 1),
#   (642, 1),
#   (643, 1),
#   (644, 3),
#   (645, 2),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 7),
#   (651, 1),
#   (652, 1),
#   (653, 1),
#   (654, 1),
#   (655, 1),
#   (656, 1),
#   (657, 2),
#   (658, 1),
#   (659, 2),
#   (660, 1),
#   (661, 1),
#   (662, 1),
#   (663, 1),
#   (664, 2),
#   (665, 1),
#   (666, 1),
#   (667, 1),
#   (668, 1),
#   (669, 1),
#   (670, 1),
#   (671, 1),
#   (672, 1),
#   (673, 1),
#   (674, 1),
#   (675, 3),
#   (676, 1),
#   (677, 1),
#   (678, 1),
#   (679, 1),
#   (680, 1),
#   (681, 1)],
#  [(8, 2),
#   (26, 1),
#   (27, 3),
#   (31, 1),
#   (34, 1),
#   (35, 2),
#   (40, 6),
#   (44, 1),
#   (47, 1),
#   (55, 2),
#   (65, 2),
#   (68, 12),
#   (74, 1),
#   (87, 3),
#   (91, 9),
#   (92, 2),
#   (100, 1),
#   (114, 3),
#   (126, 1),
#   (135, 1),
#   (142, 1),
#   (148, 3),
#   (161, 1),
#   (165, 1),
#   (168, 10),
#   (180, 2),
#   (183, 1),
#   (205, 1),
#   (206, 1),
#   (216, 4),
#   (219, 1),
#   (227, 1),
#   (231, 1),
#   (232, 1),
#   (241, 1),
#   (257, 4),
#   (279, 1),
#   (281, 1),
#   (296, 1),
#   (300, 1),
#   (321, 1),
#   (322, 1),
#   (349, 1),
#   (363, 1),
#   (370, 1),
#   (385, 1),
#   (387, 1),
#   (412, 1),
#   (424, 1),
#   (441, 1),
#   (448, 1),
#   (504, 1),
#   (516, 1),
#   (545, 2),
#   (557, 1),
#   (562, 5),
#   (595, 1),
#   (611, 1),
#   (673, 1),
#   (676, 2),
#   (682, 1),
#   (683, 1),
#   (684, 1),
#   (685, 1),
#   (686, 1),
#   (687, 1),
#   (688, 1),
#   (689, 1),
#   (690, 1),
#   (691, 2),
#   (692, 1),
#   (693, 1),
#   (694, 1),
#   (695, 1),
#   (696, 2),
#   (697, 2),
#   (698, 1),
#   (699, 2),
#   (700, 1),
#   (701, 1),
#   (702, 2),
#   (703, 1),
#   (704, 1),
#   (705, 1),
#   (706, 1),
#   (707, 1),
#   (708, 1),
#   (709, 3),
#   (710, 1),
#   (711, 1),
#   (712, 1),
#   (713, 3),
#   (714, 2),
#   (715, 1),
#   (716, 1),
#   (717, 1),
#   (718, 1),
#   (719, 1),
#   (720, 2),
#   (721, 1),
#   (722, 1),
#   (723, 1),
#   (724, 1),
#   (725, 2),
#   (726, 1),
#   (727, 1),
#   (728, 1),
#   (729, 1),
#   (730, 1),
#   (731, 1),
#   (732, 1),
#   (733, 1),
#   (734, 2),
#   (735, 1),
#   (736, 1),
#   (737, 1),
#   (738, 1),
#   (739, 1),
#   (740, 1),
#   (741, 1),
#   (742, 1),
#   (743, 1),
#   (744, 1),
#   (745, 3)],
#  [(13, 1),
#   (15, 1),
#   (16, 1),
#   (19, 2),
#   (27, 13),
#   (34, 1),
#   (46, 2),
#   (47, 11),
#   (48, 2),
#   (50, 1),
#   (51, 3),
#   (58, 4),
#   (65, 1),
#   (68, 6),
#   (71, 4),
#   (74, 2),
#   (92, 1),
#   (130, 1),
#   (135, 1),
#   (137, 1),
#   (148, 3),
#   (157, 3),
#   (170, 1),
#   (171, 1),
#   (176, 2),
#   (192, 1),
#   (232, 5),
#   (247, 1),
#   (273, 7),
#   (290, 1),
#   (296, 1),
#   (300, 1),
#   (304, 3),
#   (305, 2),
#   (308, 1),
#   (353, 3),
#   (359, 3),
#   (372, 1),
#   (380, 3),
#   (387, 1),
#   (410, 1),
#   (447, 2),
#   (474, 2),
#   (478, 1),
#   (495, 1),
#   (503, 1),
#   (547, 2),
#   (585, 1),
#   (615, 5),
#   (637, 2),
#   (653, 1),
#   (656, 1),
#   (664, 11),
#   (672, 1),
#   (677, 2),
#   (710, 5),
#   (711, 2),
#   (719, 6),
#   (733, 1),
#   (746, 2),
#   (747, 1),
#   (748, 2),
#   (749, 1),
#   (750, 6),
#   (751, 1),
#   (752, 1),
#   (753, 1),
#   (754, 1),
#   (755, 1),
#   (756, 1),
#   (757, 2),
#   (758, 1),
#   (759, 1),
#   (760, 1),
#   (761, 2),
#   (762, 1),
#   (763, 1),
#   (764, 1),
#   (765, 4),
#   (766, 1),
#   (767, 2),
#   (768, 1),
#   (769, 1),
#   (770, 1),
#   (771, 1),
#   (772, 1),
#   (773, 1),
#   (774, 2),
#   (775, 2),
#   (776, 1),
#   (777, 1),
#   (778, 2),
#   (779, 1),
#   (780, 2),
#   (781, 2),
#   (782, 3),
#   (783, 1),
#   (784, 2),
#   (785, 1),
#   (786, 1),
#   (787, 1),
#   (788, 1),
#   (789, 1),
#   (790, 1),
#   (791, 1),
#   (792, 1),
#   (793, 1),
#   (794, 2),
#   (795, 1),
#   (796, 1),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 3),
#   (801, 3)],
#  [(0, 5),
#   (2, 1),
#   (3, 1),
#   (8, 10),
#   (9, 3),
#   (10, 2),
#   (13, 2),
#   (16, 3),
#   (23, 2),
#   (26, 1),
#   (27, 7),
#   (31, 6),
#   (40, 1),
#   (50, 1),
#   (51, 1),
#   (52, 2),
#   (55, 1),
#   (60, 3),
#   (63, 1),
#   (65, 2),
#   (68, 42),
#   (71, 1),
#   (73, 1),
#   (74, 1),
#   (76, 2),
#   (81, 1),
#   (83, 2),
#   (85, 1),
#   (87, 3),
#   (91, 10),
#   (94, 1),
#   (97, 2),
#   (100, 1),
#   (112, 1),
#   (113, 2),
#   (115, 9),
#   (125, 2),
#   (126, 2),
#   (127, 17),
#   (130, 1),
#   (134, 2),
#   (137, 1),
#   (146, 1),
#   (148, 2),
#   (158, 3),
#   (161, 1),
#   (163, 1),
#   (168, 10),
#   (176, 1),
#   (181, 1),
#   (184, 3),
#   (186, 2),
#   (193, 1),
#   (196, 1),
#   (199, 1),
#   (205, 2),
#   (210, 1),
#   (216, 1),
#   (221, 1),
#   (231, 5),
#   (233, 1),
#   (245, 2),
#   (247, 3),
#   (248, 1),
#   (259, 3),
#   (260, 4),
#   (268, 4),
#   (270, 1),
#   (273, 3),
#   (274, 1),
#   (275, 2),
#   (281, 4),
#   (290, 1),
#   (291, 1),
#   (297, 1),
#   (308, 10),
#   (310, 1),
#   (328, 1),
#   (331, 2),
#   (335, 1),
#   (336, 4),
#   (337, 1),
#   (353, 1),
#   (355, 2),
#   (360, 3),
#   (364, 2),
#   (372, 7),
#   (380, 1),
#   (385, 2),
#   (403, 1),
#   (414, 2),
#   (423, 3),
#   (426, 1),
#   (440, 4),
#   (447, 2),
#   (448, 1),
#   (453, 1),
#   (460, 1),
#   (466, 1),
#   (468, 1),
#   (471, 2),
#   (473, 2),
#   (474, 1),
#   (478, 3),
#   (479, 1),
#   (480, 1),
#   (483, 3),
#   (496, 2),
#   (500, 4),
#   (510, 2),
#   (514, 1),
#   (520, 2),
#   (534, 1),
#   (540, 1),
#   (555, 1),
#   (558, 2),
#   (568, 2),
#   (576, 2),
#   (580, 1),
#   (590, 4),
#   (594, 1),
#   (595, 1),
#   (619, 1),
#   (631, 1),
#   (632, 1),
#   (642, 1),
#   (647, 3),
#   (653, 1),
#   (655, 1),
#   (660, 2),
#   (666, 1),
#   (667, 2),
#   (669, 1),
#   (702, 1),
#   (709, 1),
#   (715, 1),
#   (745, 3),
#   (754, 1),
#   (764, 1),
#   (770, 1),
#   (780, 1),
#   (790, 1),
#   (802, 1),
#   (803, 1),
#   (804, 1),
#   (805, 2),
#   (806, 2),
#   (807, 1),
#   (808, 1),
#   (809, 1),
#   (810, 1),
#   (811, 2),
#   (812, 1),
#   (813, 2),
#   (814, 1),
#   (815, 1),
#   (816, 1),
#   (817, 1),
#   (818, 1),
#   (819, 1),
#   (820, 1),
#   (821, 1),
#   (822, 2),
#   (823, 1),
#   (824, 1),
#   (825, 1),
#   (826, 3),
#   (827, 1),
#   (828, 1),
#   (829, 1),
#   (830, 1),
#   (831, 11),
#   (832, 1),
#   (833, 1),
#   (834, 1),
#   (835, 1),
#   (836, 1),
#   (837, 2),
#   (838, 2),
#   (839, 2),
#   (840, 1),
#   (841, 1),
#   (842, 1),
#   (843, 3),
#   (844, 2),
#   (845, 1),
#   (846, 1),
#   (847, 1),
#   (848, 5),
#   (849, 1),
#   (850, 1),
#   (851, 1),
#   (852, 1),
#   (853, 1),
#   (854, 1),
#   (855, 1),
#   (856, 1),
#   (857, 1),
#   (858, 1),
#   (859, 1),
#   (860, 1),
#   (861, 2),
#   (862, 1),
#   (863, 1),
#   (864, 1),
#   (865, 1),
#   (866, 1),
#   (867, 1),
#   (868, 1),
#   (869, 1),
#   (870, 1),
#   (871, 3),
#   (872, 1),
#   (873, 1),
#   (874, 1),
#   (875, 1),
#   (876, 2),
#   (877, 5),
#   (878, 2),
#   (879, 2),
#   (880, 1),
#   (881, 4),
#   (882, 1),
#   (883, 1),
#   (884, 1),
#   (885, 1),
#   (886, 1),
#   (887, 1),
#   (888, 1),
#   (889, 1),
#   (890, 2),
#   (891, 1),
#   (892, 1),
#   (893, 1),
#   (894, 1),
#   (895, 1),
#   (896, 1),
#   (897, 1),
#   (898, 1),
#   (899, 1),
#   (900, 1),
#   (901, 1),
#   (902, 1),
#   (903, 1),
#   (904, 2),
#   (905, 1),
#   (906, 1),
#   (907, 4),
#   (908, 1),
#   (909, 2),
#   (910, 1),
#   (911, 1),
#   (912, 1),
#   (913, 1),
#   (914, 1),
#   (915, 1),
#   (916, 1),
#   (917, 1),
#   (918, 3),
#   (919, 1),
#   (920, 1),
#   (921, 1),
#   (922, 1),
#   (923, 1),
#   (924, 1),
#   (925, 7),
#   (926, 2),
#   (927, 1),
#   (928, 1),
#   (929, 1),
#   (930, 1),
#   (931, 1),
#   (932, 1),
#   (933, 1),
#   (934, 1),
#   (935, 1),
#   (936, 1),
#   (937, 1),
#   (938, 2),
#   (939, 2),
#   (940, 1),
#   (941, 3),
#   (942, 1),
#   (943, 1),
#   (944, 1),
#   (945, 1),
#   (946, 2),
#   (947, 1),
#   (948, 1),
#   (949, 1),
#   (950, 3),
#   (951, 1),
#   (952, 1),
#   (953, 1),
#   (954, 1),
#   (955, 6),
#   (956, 1),
#   (957, 1),
#   (958, 1),
#   (959, 1),
#   (960, 1),
#   (961, 1),
#   (962, 2),
#   (963, 1),
#   (964, 1),
#   (965, 1),
#   (966, 2),
#   (967, 8),
#   (968, 1),
#   (969, 1),
#   (970, 1),
#   (971, 1),
#   (972, 1),
#   (973, 1),
#   (974, 1),
#   (975, 1),
#   (976, 2),
#   (977, 1),
#   (978, 1),
#   (979, 1),
#   (980, 1),
#   (981, 1),
#   (982, 1),
#   (983, 1),
#   (984, 1),
#   (985, 2),
#   (986, 1),
#   (987, 1),
#   (988, 1),
#   (989, 1),
#   (990, 3),
#   (991, 1),
#   (992, 1),
#   (993, 1),
#   (994, 1),
#   (995, 3),
#   (996, 2),
#   (997, 1),
#   (998, 1),
#   (999, 1),
#   (1000, 3),
#   (1001, 1),
#   (1002, 3),
#   (1003, 3),
#   (1004, 1),
#   (1005, 1),
#   (1006, 1),
#   (1007, 1),
#   (1008, 1),
#   (1009, 1),
#   (1010, 5)],
#  [(2, 2),
#   (8, 5),
#   (9, 2),
#   (14, 1),
#   (19, 1),
#   (27, 6),
#   (34, 1),
#   (35, 1),
#   (40, 4),
#   (51, 2),
#   (52, 1),
#   (58, 2),
#   (68, 11),
#   (87, 1),
#   (88, 1),
#   (91, 5),
#   (92, 1),
#   (93, 2),
#   (114, 2),
#   (168, 5),
#   (170, 1),
#   (183, 2),
#   (201, 1),
#   (216, 4),
#   (219, 1),
#   (222, 1),
#   (231, 1),
#   (232, 3),
#   (247, 2),
#   (249, 1),
#   (257, 4),
#   (263, 1),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (273, 1),
#   (277, 1),
#   (291, 1),
#   (299, 1),
#   (302, 1),
#   (307, 1),
#   (310, 1),
#   (353, 1),
#   (372, 3),
#   (385, 1),
#   (387, 1),
#   (392, 1),
#   (444, 1),
#   (447, 2),
#   (471, 4),
#   (473, 1),
#   (474, 1),
#   (537, 4),
#   (544, 4),
#   (555, 1),
#   (592, 1),
#   (619, 1),
#   (627, 1),
#   (650, 3),
#   (660, 1),
#   (664, 1),
#   (667, 1),
#   (676, 3),
#   (685, 1),
#   (688, 1),
#   (697, 1),
#   (711, 1),
#   (712, 1),
#   (722, 2),
#   (726, 1),
#   (727, 1),
#   (734, 3),
#   (744, 1),
#   (758, 1),
#   (779, 1),
#   (840, 1),
#   (887, 1),
#   (907, 3),
#   (917, 1),
#   (1011, 1),
#   (1012, 1),
#   (1013, 1),
#   (1014, 1),
#   (1015, 1),
#   (1016, 1),
#   (1017, 1),
#   (1018, 1),
#   (1019, 2),
#   (1020, 2),
#   (1021, 1),
#   (1022, 1),
#   (1023, 1),
#   (1024, 1),
#   (1025, 1),
#   (1026, 1),
#   (1027, 1),
#   (1028, 4),
#   (1029, 1),
#   (1030, 1),
#   (1031, 1),
#   (1032, 1),
#   (1033, 1),
#   (1034, 1),
#   (1035, 1),
#   (1036, 1),
#   (1037, 1),
#   (1038, 1),
#   (1039, 1),
#   (1040, 1),
#   (1041, 1)],
#  [(0, 1),
#   (2, 1),
#   (7, 1),
#   (8, 3),
#   (9, 1),
#   (12, 1),
#   (26, 2),
#   (27, 6),
#   (32, 1),
#   (34, 2),
#   (38, 1),
#   (41, 1),
#   (52, 2),
#   (55, 3),
#   (68, 10),
#   (81, 1),
#   (87, 6),
#   (91, 4),
#   (92, 4),
#   (118, 1),
#   (127, 1),
#   (129, 1),
#   (153, 1),
#   (161, 1),
#   (168, 4),
#   (190, 2),
#   (201, 4),
#   (213, 1),
#   (216, 1),
#   (222, 2),
#   (227, 1),
#   (232, 1),
#   (247, 2),
#   (257, 1),
#   (269, 1),
#   (270, 1),
#   (307, 2),
#   (329, 2),
#   (355, 4),
#   (357, 1),
#   (367, 3),
#   (392, 1),
#   (426, 1),
#   (481, 1),
#   (484, 8),
#   (504, 2),
#   (578, 1),
#   (580, 3),
#   (594, 1),
#   (619, 2),
#   (623, 1),
#   (646, 4),
#   (650, 7),
#   (660, 1),
#   (664, 4),
#   (667, 1),
#   (669, 2),
#   (672, 1),
#   (692, 1),
#   (709, 2),
#   (742, 1),
#   (773, 1),
#   (808, 2),
#   (955, 1),
#   (971, 1),
#   (1027, 2),
#   (1042, 1),
#   (1043, 7),
#   (1044, 1),
#   (1045, 1),
#   (1046, 1),
#   (1047, 1),
#   (1048, 5),
#   (1049, 1),
#   (1050, 2),
#   (1051, 1),
#   (1052, 1),
#   (1053, 1),
#   (1054, 1),
#   (1055, 1),
#   (1056, 1),
#   (1057, 1),
#   (1058, 1),
#   (1059, 1),
#   (1060, 1),
#   (1061, 1),
#   (1062, 1),
#   (1063, 2),
#   (1064, 1),
#   (1065, 1),
#   (1066, 1),
#   (1067, 1),
#   (1068, 1),
#   (1069, 1),
#   (1070, 1),
#   (1071, 1),
#   (1072, 3)],
#  [(8, 1),
#   (9, 1),
#   (13, 1),
#   (16, 1),
#   (24, 1),
#   (27, 2),
#   (32, 2),
#   (34, 3),
#   (35, 1),
#   (41, 1),
#   (43, 2),
#   (57, 1),
#   (65, 3),
#   (68, 8),
#   (91, 6),
#   (92, 1),
#   (105, 1),
#   (111, 1),
#   (115, 1),
#   (124, 1),
#   (148, 3),
#   (168, 6),
#   (169, 1),
#   (192, 1),
#   (210, 4),
#   (216, 2),
#   (231, 2),
#   (251, 1),
#   (267, 2),
#   (273, 2),
#   (299, 1),
#   (304, 5),
#   (307, 1),
#   (308, 1),
#   (314, 1),
#   (327, 1),
#   (329, 2),
#   (339, 1),
#   (353, 2),
#   (360, 1),
#   (363, 1),
#   (382, 2),
#   (418, 1),
#   (433, 1),
#   (449, 1),
#   (459, 2),
#   (467, 1),
#   (507, 1),
#   (585, 1),
#   (589, 2),
#   (592, 3),
#   (600, 1),
#   (601, 1),
#   (615, 1),
#   (642, 1),
#   (672, 1),
#   (679, 1),
#   (704, 3),
#   (797, 1),
#   (1028, 1),
#   (1034, 1),
#   (1062, 1),
#   (1073, 1),
#   (1074, 1),
#   (1075, 1),
#   (1076, 1),
#   (1077, 1),
#   (1078, 2),
#   (1079, 1),
#   (1080, 1),
#   (1081, 1),
#   (1082, 2),
#   (1083, 1),
#   (1084, 1),
#   (1085, 1),
#   (1086, 4),
#   (1087, 1),
#   (1088, 2),
#   (1089, 2),
#   (1090, 1),
#   (1091, 2),
#   (1092, 2),
#   (1093, 9),
#   (1094, 1),
#   (1095, 1),
#   (1096, 1),
#   (1097, 1),
#   (1098, 3),
#   (1099, 1),
#   (1100, 9),
#   (1101, 2),
#   (1102, 3),
#   (1103, 1),
#   (1104, 1),
#   (1105, 2),
#   (1106, 1)],
#  [(2, 1),
#   (3, 3),
#   (34, 1),
#   (40, 1),
#   (44, 1),
#   (52, 1),
#   (65, 1),
#   (68, 13),
#   (69, 1),
#   (74, 1),
#   (91, 5),
#   (92, 1),
#   (97, 2),
#   (107, 2),
#   (114, 7),
#   (115, 1),
#   (122, 1),
#   (148, 2),
#   (162, 2),
#   (168, 5),
#   (176, 1),
#   (178, 2),
#   (179, 1),
#   (191, 2),
#   (194, 1),
#   (198, 4),
#   (208, 1),
#   (213, 1),
#   (214, 1),
#   (216, 1),
#   (219, 1),
#   (226, 1),
#   (227, 2),
#   (231, 3),
#   (238, 1),
#   (239, 1),
#   (241, 2),
#   (244, 1),
#   (245, 1),
#   (247, 4),
#   (251, 1),
#   (257, 1),
#   (260, 7),
#   (262, 1),
#   (275, 2),
#   (290, 1),
#   (297, 2),
#   (298, 1),
#   (300, 1),
#   (305, 1),
#   (327, 1),
#   (329, 1),
#   (474, 2),
#   (478, 2),
#   (518, 1),
#   (562, 1),
#   (629, 1),
#   (703, 2),
#   (815, 1),
#   (860, 1),
#   (917, 1),
#   (1033, 1),
#   (1050, 1),
#   (1075, 2),
#   (1077, 1),
#   (1107, 1),
#   (1108, 1),
#   (1109, 2),
#   (1110, 1),
#   (1111, 1),
#   (1112, 1),
#   (1113, 1),
#   (1114, 1),
#   (1115, 1),
#   (1116, 1),
#   (1117, 1),
#   (1118, 1),
#   (1119, 2),
#   (1120, 1),
#   (1121, 1),
#   (1122, 1),
#   (1123, 1),
#   (1124, 1),
#   (1125, 1),
#   (1126, 1),
#   (1127, 2),
#   (1128, 1),
#   (1129, 1),
#   (1130, 1),
#   (1131, 1),
#   (1132, 1),
#   (1133, 1),
#   (1134, 1),
#   (1135, 2),
#   (1136, 1),
#   (1137, 1)],
#  [(13, 1),
#   (16, 2),
#   (19, 3),
#   (27, 17),
#   (32, 1),
#   (34, 1),
#   (44, 1),
#   (46, 2),
#   (47, 13),
#   (48, 2),
#   (50, 1),
#   (51, 2),
#   (55, 1),
#   (58, 11),
#   (65, 1),
#   (68, 7),
#   (71, 2),
#   (74, 2),
#   (92, 1),
#   (93, 1),
#   (126, 7),
#   (130, 1),
#   (135, 1),
#   (137, 1),
#   (140, 1),
#   (148, 3),
#   (157, 3),
#   (167, 1),
#   (170, 1),
#   (188, 3),
#   (192, 7),
#   (232, 2),
#   (241, 1),
#   (247, 1),
#   (257, 1),
#   (267, 1),
#   (273, 11),
#   (290, 1),
#   (296, 1),
#   (297, 1),
#   (299, 3),
#   (300, 1),
#   (304, 4),
#   (307, 1),
#   (308, 2),
#   (330, 1),
#   (353, 2),
#   (359, 5),
#   (372, 1),
#   (380, 3),
#   (382, 1),
#   (387, 1),
#   (410, 1),
#   (424, 2),
#   (435, 1),
#   (447, 2),
#   (460, 1),
#   (466, 1),
#   (474, 8),
#   (478, 1),
#   (488, 1),
#   (503, 1),
#   (547, 1),
#   (551, 3),
#   (562, 7),
#   (585, 1),
#   (615, 9),
#   (647, 1),
#   (653, 1),
#   (664, 13),
#   (666, 1),
#   (672, 1),
#   (677, 2),
#   (704, 2),
#   (710, 2),
#   (711, 2),
#   (719, 5),
#   (733, 1),
#   (746, 2),
#   (747, 1),
#   (749, 1),
#   (750, 6),
#   (752, 1),
#   (753, 1),
#   (754, 1),
#   (757, 2),
#   (758, 1),
#   (759, 1),
#   (760, 1),
#   (761, 3),
#   (763, 1),
#   (764, 1),
#   (765, 5),
#   (766, 1),
#   (768, 1),
#   (769, 1),
#   (771, 2),
#   (772, 1),
#   (773, 3),
#   (774, 1),
#   (776, 1),
#   (777, 1),
#   (779, 1),
#   (780, 2),
#   (782, 2),
#   (783, 1),
#   (784, 4),
#   (785, 1),
#   (787, 1),
#   (788, 2),
#   (791, 1),
#   (792, 1),
#   (793, 1),
#   (795, 1),
#   (796, 1),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 2),
#   (801, 3),
#   (863, 1),
#   (963, 1),
#   (1060, 1),
#   (1138, 2),
#   (1139, 1),
#   (1140, 1),
#   (1141, 1),
#   (1142, 1),
#   (1143, 1),
#   (1144, 1),
#   (1145, 1),
#   (1146, 1),
#   (1147, 1),
#   (1148, 1),
#   (1149, 1),
#   (1150, 1),
#   (1151, 3),
#   (1152, 1),
#   (1153, 1),
#   (1154, 1),
#   (1155, 2),
#   (1156, 2),
#   (1157, 1),
#   (1158, 1),
#   (1159, 7),
#   (1160, 1),
#   (1161, 2),
#   (1162, 1)],
#  [(8, 3),
#   (26, 1),
#   (27, 6),
#   (31, 1),
#   (32, 2),
#   (34, 1),
#   (35, 2),
#   (39, 1),
#   (40, 5),
#   (41, 2),
#   (47, 1),
#   (52, 1),
#   (54, 1),
#   (65, 5),
#   (68, 8),
#   (74, 1),
#   (87, 6),
#   (91, 8),
#   (92, 3),
#   (93, 1),
#   (99, 1),
#   (107, 1),
#   (114, 1),
#   (118, 1),
#   (132, 1),
#   (134, 1),
#   (140, 1),
#   (142, 2),
#   (148, 6),
#   (161, 1),
#   (166, 1),
#   (168, 8),
#   (182, 2),
#   (184, 1),
#   (201, 1),
#   (216, 4),
#   (222, 1),
#   (227, 1),
#   (231, 1),
#   (232, 1),
#   (241, 2),
#   (245, 3),
#   (247, 2),
#   (257, 4),
#   (267, 1),
#   (268, 5),
#   (274, 1),
#   (275, 1),
#   (292, 1),
#   (302, 1),
#   (304, 4),
#   (307, 1),
#   (308, 3),
#   (359, 1),
#   (362, 2),
#   (363, 2),
#   (395, 1),
#   (399, 1),
#   (425, 1),
#   (455, 1),
#   (474, 1),
#   (479, 1),
#   (516, 1),
#   (519, 1),
#   (523, 1),
#   (534, 1),
#   (562, 3),
#   (589, 1),
#   (628, 1),
#   (650, 1),
#   (660, 2),
#   (664, 1),
#   (667, 1),
#   (676, 4),
#   (685, 1),
#   (697, 3),
#   (709, 1),
#   (711, 1),
#   (722, 1),
#   (726, 2),
#   (727, 1),
#   (736, 1),
#   (738, 1),
#   (741, 1),
#   (744, 1),
#   (748, 3),
#   (758, 1),
#   (760, 1),
#   (763, 1),
#   (773, 1),
#   (817, 1),
#   (980, 1),
#   (1028, 2),
#   (1029, 1),
#   (1033, 1),
#   (1036, 1),
#   (1043, 2),
#   (1044, 1),
#   (1112, 2),
#   (1128, 1),
#   (1163, 1),
#   (1164, 1),
#   (1165, 1),
#   (1166, 7),
#   (1167, 3),
#   (1168, 1),
#   (1169, 1),
#   (1170, 1),
#   (1171, 1),
#   (1172, 1),
#   (1173, 1),
#   (1174, 1),
#   (1175, 2),
#   (1176, 1),
#   (1177, 1),
#   (1178, 1),
#   (1179, 1),
#   (1180, 2),
#   (1181, 1),
#   (1182, 1),
#   (1183, 1),
#   (1184, 1),
#   (1185, 1),
#   (1186, 1),
#   (1187, 1),
#   (1188, 1),
#   (1189, 1),
#   (1190, 2),
#   (1191, 1),
#   (1192, 2),
#   (1193, 1),
#   (1194, 5),
#   (1195, 1),
#   (1196, 1),
#   (1197, 1),
#   (1198, 1),
#   (1199, 1),
#   (1200, 4),
#   (1201, 1),
#   (1202, 2),
#   (1203, 1),
#   (1204, 1)],
#  [(0, 2),
#   (8, 5),
#   (26, 2),
#   (27, 3),
#   (34, 2),
#   (35, 1),
#   (41, 1),
#   (52, 1),
#   (68, 6),
#   (74, 2),
#   (77, 1),
#   (85, 4),
#   (87, 4),
#   (92, 1),
#   (101, 1),
#   (107, 1),
#   (114, 3),
#   (117, 1),
#   (120, 1),
#   (126, 1),
#   (129, 1),
#   (134, 1),
#   (137, 1),
#   (148, 1),
#   (157, 7),
#   (158, 1),
#   (159, 1),
#   (161, 1),
#   (162, 1),
#   (172, 7),
#   (191, 1),
#   (215, 1),
#   (227, 1),
#   (232, 1),
#   (240, 1),
#   (245, 1),
#   (247, 1),
#   (257, 4),
#   (259, 1),
#   (269, 1),
#   (270, 1),
#   (300, 1),
#   (305, 2),
#   (327, 1),
#   (346, 1),
#   (387, 3),
#   (398, 1),
#   (421, 1),
#   (427, 2),
#   (430, 1),
#   (432, 1),
#   (441, 1),
#   (446, 2),
#   (467, 1),
#   (479, 1),
#   (495, 1),
#   (537, 2),
#   (544, 2),
#   (568, 1),
#   (573, 1),
#   (637, 2),
#   (660, 1),
#   (664, 2),
#   (676, 1),
#   (685, 1),
#   (697, 1),
#   (726, 1),
#   (773, 1),
#   (815, 1),
#   (842, 1),
#   (916, 1),
#   (926, 1),
#   (1028, 1),
#   (1031, 1),
#   (1033, 1),
#   (1047, 1),
#   (1061, 1),
#   (1075, 2),
#   (1109, 1),
#   (1112, 1),
#   (1124, 1),
#   (1129, 1),
#   (1135, 1),
#   (1205, 1),
#   (1206, 1),
#   (1207, 1),
#   (1208, 1),
#   (1209, 1),
#   (1210, 2),
#   (1211, 1),
#   (1212, 2),
#   (1213, 1),
#   (1214, 1),
#   (1215, 1),
#   (1216, 1),
#   (1217, 1),
#   (1218, 1),
#   (1219, 1),
#   (1220, 1),
#   (1221, 1),
#   (1222, 1),
#   (1223, 1),
#   (1224, 1),
#   (1225, 1),
#   (1226, 1),
#   (1227, 1),
#   (1228, 1),
#   (1229, 1),
#   (1230, 1),
#   (1231, 2),
#   (1232, 2),
#   (1233, 1),
#   (1234, 1),
#   (1235, 1)],
#  [(0, 1),
#   (3, 3),
#   (8, 2),
#   (13, 1),
#   (23, 1),
#   (27, 5),
#   (40, 5),
#   (42, 1),
#   (45, 1),
#   (46, 2),
#   (51, 2),
#   (65, 2),
#   (68, 22),
#   (69, 1),
#   (72, 2),
#   (81, 2),
#   (87, 2),
#   (93, 2),
#   (94, 1),
#   (100, 1),
#   (110, 1),
#   (113, 1),
#   (114, 3),
#   (115, 2),
#   (125, 1),
#   (127, 5),
#   (134, 1),
#   (148, 2),
#   (161, 1),
#   (163, 1),
#   (168, 4),
#   (176, 7),
#   (181, 1),
#   (186, 6),
#   (190, 1),
#   (193, 1),
#   (196, 1),
#   (205, 2),
#   (206, 1),
#   (209, 1),
#   (210, 2),
#   (213, 1),
#   (231, 1),
#   (233, 1),
#   (245, 1),
#   (254, 4),
#   (279, 3),
#   (281, 1),
#   (297, 1),
#   (322, 2),
#   (325, 1),
#   (326, 3),
#   (355, 2),
#   (356, 1),
#   (359, 1),
#   (364, 1),
#   (370, 1),
#   (398, 1),
#   (414, 3),
#   (415, 1),
#   (423, 2),
#   (426, 2),
#   (427, 1),
#   (435, 2),
#   (447, 3),
#   (448, 1),
#   (459, 1),
#   (471, 1),
#   (473, 1),
#   (474, 4),
#   (483, 2),
#   (487, 1),
#   (499, 1),
#   (501, 1),
#   (530, 1),
#   (539, 1),
#   (547, 1),
#   (555, 1),
#   (585, 4),
#   (594, 2),
#   (605, 1),
#   (616, 1),
#   (647, 1),
#   (664, 5),
#   (667, 1),
#   (686, 1),
#   (702, 1),
#   (704, 1),
#   (734, 1),
#   (754, 7),
#   (759, 1),
#   (769, 1),
#   (794, 1),
#   (798, 1),
#   (811, 6),
#   (812, 1),
#   (813, 2),
#   (824, 1),
#   (827, 1),
#   (831, 1),
#   (833, 1),
#   (839, 1),
#   (840, 1),
#   (841, 1),
#   (843, 1),
#   (846, 1),
#   (849, 1),
#   (856, 1),
#   (873, 1),
#   (877, 2),
#   (878, 5),
#   (906, 1),
#   (909, 1),
#   (928, 1),
#   (935, 1),
#   (941, 5),
#   (947, 1),
#   (949, 1),
#   (955, 3),
#   (961, 1),
#   (976, 1),
#   (986, 1),
#   (995, 1),
#   (999, 1),
#   (1044, 1),
#   (1053, 1),
#   (1054, 1),
#   (1057, 1),
#   (1076, 1),
#   (1104, 2),
#   (1139, 1),
#   (1156, 1),
#   (1181, 1),
#   (1187, 1),
#   (1222, 2),
#   (1236, 1),
#   (1237, 4),
#   (1238, 1),
#   (1239, 1),
#   (1240, 1),
#   (1241, 2),
#   (1242, 1),
#   (1243, 2),
#   (1244, 1),
#   (1245, 1),
#   (1246, 1),
#   (1247, 2),
#   (1248, 1),
#   (1249, 1),
#   (1250, 1),
#   (1251, 1),
#   (1252, 1),
#   (1253, 1),
#   (1254, 1),
#   (1255, 1),
#   (1256, 1),
#   (1257, 1),
#   (1258, 1),
#   (1259, 1),
#   (1260, 1),
#   (1261, 1),
#   (1262, 1),
#   (1263, 3),
#   (1264, 1),
#   (1265, 1),
#   (1266, 7),
#   (1267, 1),
#   (1268, 1),
#   (1269, 1),
#   (1270, 1),
#   (1271, 1),
#   (1272, 3),
#   (1273, 2),
#   (1274, 1),
#   (1275, 1),
#   (1276, 1),
#   (1277, 2),
#   (1278, 1),
#   (1279, 1),
#   (1280, 2),
#   (1281, 1),
#   (1282, 1),
#   (1283, 1),
#   (1284, 1),
#   (1285, 1),
#   (1286, 1),
#   (1287, 1),
#   (1288, 2),
#   (1289, 1),
#   (1290, 1),
#   (1291, 1),
#   (1292, 2),
#   (1293, 4),
#   (1294, 1),
#   (1295, 1),
#   (1296, 1),
#   (1297, 1),
#   (1298, 1),
#   (1299, 1),
#   (1300, 1),
#   (1301, 1),
#   (1302, 9),
#   (1303, 1),
#   (1304, 1),
#   (1305, 1),
#   (1306, 1),
#   (1307, 1),
#   (1308, 1),
#   (1309, 1),
#   (1310, 1),
#   (1311, 5),
#   (1312, 1),
#   (1313, 1),
#   (1314, 1),
#   (1315, 1),
#   (1316, 1),
#   (1317, 1),
#   (1318, 9),
#   (1319, 2),
#   (1320, 2),
#   (1321, 1),
#   (1322, 1),
#   (1323, 1),
#   (1324, 1),
#   (1325, 2),
#   (1326, 1),
#   (1327, 1),
#   (1328, 2),
#   (1329, 1),
#   (1330, 1),
#   (1331, 2),
#   (1332, 2),
#   (1333, 1),
#   (1334, 1),
#   (1335, 1),
#   (1336, 1),
#   (1337, 1),
#   (1338, 1),
#   (1339, 2),
#   (1340, 1),
#   (1341, 6),
#   (1342, 3),
#   (1343, 1),
#   (1344, 1),
#   (1345, 1),
#   (1346, 1),
#   (1347, 1),
#   (1348, 1),
#   (1349, 15),
#   (1350, 1),
#   (1351, 2),
#   (1352, 2),
#   (1353, 1),
#   (1354, 2),
#   (1355, 1),
#   (1356, 1),
#   (1357, 4),
#   (1358, 1),
#   (1359, 2),
#   (1360, 1),
#   (1361, 1),
#   (1362, 1),
#   (1363, 1),
#   (1364, 1),
#   (1365, 1),
#   (1366, 1),
#   (1367, 1),
#   (1368, 1),
#   (1369, 1),
#   (1370, 2),
#   (1371, 1),
#   (1372, 2),
#   (1373, 1),
#   (1374, 1),
#   (1375, 1),
#   (1376, 1),
#   (1377, 1),
#   (1378, 1),
#   (1379, 1),
#   (1380, 1),
#   (1381, 1),
#   (1382, 1),
#   (1383, 1),
#   (1384, 1),
#   (1385, 1),
#   (1386, 2),
#   (1387, 1),
#   (1388, 1),
#   (1389, 2),
#   (1390, 1),
#   (1391, 1),
#   (1392, 1),
#   (1393, 1),
#   (1394, 1),
#   (1395, 1),
#   (1396, 1),
#   (1397, 1),
#   (1398, 1),
#   (1399, 1),
#   (1400, 1),
#   (1401, 1),
#   (1402, 6),
#   (1403, 2),
#   (1404, 2),
#   (1405, 1),
#   (1406, 1),
#   (1407, 1),
#   (1408, 1),
#   (1409, 3),
#   (1410, 2),
#   (1411, 3),
#   (1412, 1),
#   (1413, 1),
#   (1414, 1),
#   (1415, 1),
#   (1416, 1),
#   (1417, 1),
#   (1418, 1),
#   (1419, 1),
#   (1420, 6),
#   (1421, 1),
#   (1422, 1),
#   (1423, 1),
#   (1424, 1),
#   (1425, 1),
#   (1426, 1),
#   (1427, 1),
#   (1428, 1),
#   (1429, 1),
#   (1430, 2),
#   (1431, 1),
#   (1432, 1),
#   (1433, 1)],
#  [(0, 1),
#   (3, 1),
#   (12, 1),
#   (13, 2),
#   (23, 1),
#   (27, 7),
#   (32, 1),
#   (40, 6),
#   (51, 3),
#   (52, 2),
#   (58, 3),
#   (61, 1),
#   (65, 18),
#   (68, 26),
#   (69, 3),
#   (74, 2),
#   (87, 1),
#   (91, 7),
#   (94, 1),
#   (104, 1),
#   (110, 1),
#   (114, 12),
#   (115, 6),
#   (116, 1),
#   (117, 1),
#   (126, 4),
#   (127, 7),
#   (132, 1),
#   (137, 1),
#   (140, 2),
#   (146, 1),
#   (148, 18),
#   (161, 1),
#   (162, 1),
#   (163, 1),
#   (168, 12),
#   (169, 4),
#   (176, 1),
#   (181, 1),
#   (182, 2),
#   (186, 2),
#   (193, 1),
#   (196, 1),
#   (205, 2),
#   (210, 1),
#   (213, 3),
#   (216, 4),
#   (231, 5),
#   (233, 1),
#   (242, 1),
#   (251, 1),
#   (260, 1),
#   (267, 1),
#   (268, 1),
#   (273, 4),
#   (275, 1),
#   (277, 2),
#   (297, 3),
#   (298, 1),
#   (308, 2),
#   (327, 1),
#   (328, 1),
#   (359, 4),
#   (360, 1),
#   (362, 1),
#   (363, 1),
#   (372, 1),
#   (373, 1),
#   (387, 1),
#   (414, 1),
#   (417, 1),
#   (419, 1),
#   (425, 1),
#   (426, 3),
#   (437, 1),
#   (448, 1),
#   (459, 2),
#   (460, 1),
#   (473, 2),
#   (474, 9),
#   (477, 1),
#   (478, 1),
#   (496, 1),
#   (510, 4),
#   (516, 2),
#   (520, 2),
#   (538, 1),
#   (551, 2),
#   (555, 2),
#   (562, 6),
#   (576, 2),
#   (590, 5),
#   (592, 2),
#   (594, 1),
#   (616, 1),
#   (622, 1),
#   (629, 2),
#   (647, 1),
#   (703, 8),
#   (704, 1),
#   (717, 2),
#   (750, 2),
#   (751, 1),
#   (754, 2),
#   (765, 1),
#   (770, 1),
#   (815, 1),
#   (817, 1),
#   (827, 1),
#   (829, 3),
#   (833, 1),
#   (840, 1),
#   (841, 1),
#   (860, 1),
#   (878, 1),
#   (890, 6),
#   (895, 1),
#   (906, 1),
#   (907, 1),
#   (909, 1),
#   (916, 1),
#   (926, 2),
#   (938, 1),
#   (940, 1),
#   (949, 1),
#   (962, 1),
#   (967, 4),
#   (979, 2),
#   (981, 1),
#   (996, 1),
#   (999, 1),
#   (1015, 2),
#   (1033, 1),
#   (1038, 2),
#   (1045, 2),
#   (1107, 1),
#   (1110, 1),
#   (1115, 1),
#   (1121, 2),
#   (1128, 1),
#   (1139, 5),
#   (1153, 1),
#   (1156, 1),
#   (1168, 1),
#   (1172, 1),
#   (1242, 4),
#   (1247, 1),
#   (1256, 1),
#   (1273, 1),
#   (1276, 1),
#   (1283, 1),
#   (1295, 1),
#   (1299, 1),
#   (1332, 1),
#   (1354, 1),
#   (1418, 1),
#   (1434, 2),
#   (1435, 1),
#   (1436, 1),
#   (1437, 2),
#   (1438, 1),
#   (1439, 2),
#   (1440, 1),
#   (1441, 2),
#   (1442, 1),
#   (1443, 1),
#   (1444, 2),
#   (1445, 3),
#   (1446, 1),
#   (1447, 1),
#   (1448, 2),
#   (1449, 1),
#   (1450, 1),
#   (1451, 1),
#   (1452, 1),
#   (1453, 1),
#   (1454, 1),
#   (1455, 2),
#   (1456, 1),
#   (1457, 2),
#   (1458, 1),
#   (1459, 1),
#   (1460, 1),
#   (1461, 4),
#   (1462, 1),
#   (1463, 1),
#   (1464, 1),
#   (1465, 1),
#   (1466, 1),
#   (1467, 1),
#   (1468, 1),
#   (1469, 1),
#   (1470, 1),
#   (1471, 1),
#   (1472, 1),
#   (1473, 1),
#   (1474, 1),
#   (1475, 1),
#   (1476, 1),
#   (1477, 1),
#   (1478, 1),
#   (1479, 1),
#   (1480, 5),
#   (1481, 1),
#   (1482, 1),
#   (1483, 1),
#   (1484, 1),
#   (1485, 1),
#   (1486, 1),
#   (1487, 1),
#   (1488, 1),
#   (1489, 1),
#   (1490, 1),
#   (1491, 1),
#   (1492, 1),
#   (1493, 1),
#   (1494, 1),
#   (1495, 1),
#   (1496, 1),
#   (1497, 3),
#   (1498, 1),
#   (1499, 2),
#   (1500, 1),
#   (1501, 1),
#   (1502, 3),
#   (1503, 1),
#   (1504, 1),
#   (1505, 3),
#   (1506, 1),
#   (1507, 1),
#   (1508, 1),
#   (1509, 1),
#   (1510, 4),
#   (1511, 1),
#   (1512, 1),
#   (1513, 1),
#   (1514, 1),
#   (1515, 1),
#   (1516, 1),
#   (1517, 1),
#   (1518, 1),
#   (1519, 1),
#   (1520, 1),
#   (1521, 1),
#   (1522, 1),
#   (1523, 1),
#   (1524, 1),
#   (1525, 1),
#   (1526, 2),
#   (1527, 1),
#   (1528, 4),
#   (1529, 1),
#   (1530, 3),
#   (1531, 1),
#   (1532, 1),
#   (1533, 2),
#   (1534, 1),
#   (1535, 1),
#   (1536, 3),
#   (1537, 1),
#   (1538, 1),
#   (1539, 1),
#   (1540, 1),
#   (1541, 2),
#   (1542, 2),
#   (1543, 2),
#   (1544, 1)],
#  [(8, 3),
#   (27, 1),
#   (34, 1),
#   (40, 8),
#   (52, 1),
#   (68, 8),
#   (87, 1),
#   (91, 2),
#   (99, 1),
#   (114, 3),
#   (158, 1),
#   (164, 1),
#   (168, 2),
#   (183, 1),
#   (184, 1),
#   (188, 1),
#   (227, 1),
#   (232, 1),
#   (245, 1),
#   (275, 1),
#   (302, 4),
#   (304, 1),
#   (305, 1),
#   (314, 5),
#   (316, 1),
#   (380, 1),
#   (395, 1),
#   (427, 1),
#   (462, 1),
#   (476, 1),
#   (518, 2),
#   (629, 1),
#   (640, 1),
#   (676, 1),
#   (697, 1),
#   (722, 2),
#   (1043, 1),
#   (1545, 1),
#   (1546, 1),
#   (1547, 1),
#   (1548, 1),
#   (1549, 1),
#   (1550, 2),
#   (1551, 1),
#   (1552, 1),
#   (1553, 1),
#   (1554, 1),
#   (1555, 1)],
#  [(2, 2),
#   (3, 3),
#   (9, 1),
#   (13, 3),
#   (16, 1),
#   (17, 4),
#   (22, 1),
#   (26, 6),
#   (27, 11),
#   (31, 2),
#   (36, 1),
#   (39, 1),
#   (40, 1),
#   (45, 2),
#   (47, 12),
#   (48, 3),
#   (52, 5),
#   (54, 1),
#   (56, 1),
#   (57, 1),
#   (61, 1),
#   (65, 8),
#   (68, 24),
#   (69, 1),
#   (71, 2),
#   (72, 2),
#   (74, 4),
#   (79, 6),
#   (86, 1),
#   (87, 4),
#   (97, 1),
#   (110, 1),
#   (112, 2),
#   (114, 1),
#   (116, 4),
#   (127, 2),
#   (129, 3),
#   (130, 1),
#   (148, 9),
#   (157, 4),
#   (161, 1),
#   (163, 4),
#   (164, 1),
#   (168, 1),
#   (188, 1),
#   (192, 2),
#   (205, 1),
#   (216, 1),
#   (219, 1),
#   (231, 1),
#   (242, 1),
#   (255, 1),
#   (257, 1),
#   (259, 3),
#   (260, 1),
#   (267, 1),
#   (268, 1),
#   (269, 3),
#   (273, 5),
#   (275, 1),
#   (279, 1),
#   (281, 1),
#   (290, 1),
#   (297, 3),
#   (300, 8),
#   (301, 1),
#   (304, 4),
#   (308, 6),
#   (323, 1),
#   (335, 1),
#   (341, 1),
#   (345, 1),
#   (349, 1),
#   (351, 1),
#   (353, 1),
#   (358, 1),
#   (359, 2),
#   (360, 1),
#   (362, 1),
#   (370, 1),
#   (373, 1),
#   (378, 3),
#   (380, 11),
#   (386, 1),
#   (419, 1),
#   (423, 1),
#   (426, 1),
#   (428, 1),
#   (441, 2),
#   (456, 1),
#   (466, 1),
#   (474, 24),
#   (481, 1),
#   (483, 1),
#   (496, 1),
#   (503, 1),
#   (504, 1),
#   (511, 1),
#   (534, 2),
#   (538, 1),
#   (551, 2),
#   (555, 3),
#   (562, 1),
#   (563, 1),
#   (578, 1),
#   (584, 1),
#   (589, 3),
#   (605, 1),
#   (611, 2),
#   (615, 3),
#   (623, 5),
#   (629, 1),
#   (637, 2),
#   (640, 1),
#   (647, 1),
#   (653, 1),
#   (656, 1),
#   (659, 1),
#   (664, 13),
#   (667, 2),
#   (692, 1),
#   (704, 4),
#   (710, 3),
#   (719, 1),
#   (746, 2),
#   (754, 2),
#   (758, 1),
#   (760, 3),
#   (761, 1),
#   (769, 1),
#   (773, 1),
#   (779, 1),
#   (782, 16),
#   (783, 1),
#   (784, 2),
#   (788, 8),
#   (789, 1),
#   (791, 1),
#   (795, 2),
#   (796, 1),
#   (799, 1),
#   (800, 3),
#   (810, 1),
#   (811, 3),
#   (812, 2),
#   (813, 1),
#   (823, 1),
#   (824, 1),
#   (839, 2),
#   (845, 2),
#   (865, 1),
#   (873, 1),
#   (915, 1),
#   (917, 1),
#   (945, 1),
#   (960, 1),
#   (972, 2),
#   (974, 1),
#   (1000, 1),
#   (1043, 2),
#   (1064, 1),
#   (1123, 1),
#   (1124, 1),
#   (1142, 1),
#   (1145, 1),
#   (1151, 5),
#   (1152, 1),
#   (1158, 3),
#   (1160, 2),
#   (1161, 3),
#   (1166, 1),
#   (1169, 3),
#   (1170, 1),
#   (1184, 1),
#   (1191, 1),
#   (1192, 3),
#   (1200, 2),
#   (1210, 1),
#   (1219, 1),
#   (1228, 1),
#   (1267, 1),
#   (1282, 4),
#   (1289, 1),
#   (1301, 1),
#   (1302, 1),
#   (1308, 2),
#   (1336, 1),
#   (1339, 1),
#   (1342, 1),
#   (1359, 4),
#   (1367, 9),
#   (1393, 1),
#   (1434, 1),
#   (1443, 1),
#   (1450, 1),
#   (1499, 1),
#   (1519, 1),
#   (1535, 1),
#   (1556, 2),
#   (1557, 1),
#   (1558, 1),
#   (1559, 2),
#   (1560, 1),
#   (1561, 1),
#   (1562, 1),
#   (1563, 1),
#   (1564, 2),
#   (1565, 1),
#   (1566, 1),
#   (1567, 1),
#   (1568, 1),
#   (1569, 1),
#   (1570, 1),
#   (1571, 1),
#   (1572, 1),
#   (1573, 1),
#   (1574, 1),
#   (1575, 1),
#   (1576, 1),
#   (1577, 2),
#   (1578, 1),
#   (1579, 1),
#   (1580, 1),
#   (1581, 1),
#   (1582, 1),
#   (1583, 1),
#   (1584, 1),
#   (1585, 2),
#   (1586, 1),
#   (1587, 1),
#   (1588, 1),
#   (1589, 1),
#   (1590, 1),
#   (1591, 1),
#   (1592, 1),
#   (1593, 1),
#   (1594, 1),
#   (1595, 1),
#   (1596, 1),
#   (1597, 2),
#   (1598, 1),
#   (1599, 1),
#   (1600, 1),
#   (1601, 1),
#   (1602, 2),
#   (1603, 3),
#   (1604, 2),
#   (1605, 1),
#   (1606, 1),
#   (1607, 1),
#   (1608, 1),
#   (1609, 1),
#   (1610, 1),
#   (1611, 1),
#   (1612, 1),
#   (1613, 1),
#   (1614, 1),
#   (1615, 1),
#   (1616, 4),
#   (1617, 1),
#   (1618, 1),
#   (1619, 1),
#   (1620, 1),
#   (1621, 1),
#   (1622, 1),
#   (1623, 1),
#   (1624, 1),
#   (1625, 1),
#   (1626, 1),
#   (1627, 1),
#   (1628, 1),
#   (1629, 1),
#   (1630, 1),
#   (1631, 3),
#   (1632, 2),
#   (1633, 1),
#   (1634, 1),
#   (1635, 1),
#   (1636, 1),
#   (1637, 2),
#   (1638, 2),
#   (1639, 1),
#   (1640, 1),
#   (1641, 1),
#   (1642, 1),
#   (1643, 2),
#   (1644, 1),
#   (1645, 1),
#   (1646, 1),
#   (1647, 1),
#   (1648, 1),
#   (1649, 1),
#   (1650, 1),
#   (1651, 1),
#   (1652, 1),
#   (1653, 1),
#   (1654, 1),
#   (1655, 1),
#   (1656, 1),
#   (1657, 1),
#   (1658, 1),
#   (1659, 1),
#   (1660, 1),
#   (1661, 1),
#   (1662, 1),
#   (1663, 1),
#   (1664, 1),
#   (1665, 1),
#   (1666, 1),
#   (1667, 2),
#   (1668, 1),
#   (1669, 1),
#   (1670, 1),
#   (1671, 1),
#   (1672, 1),
#   (1673, 1),
#   (1674, 2),
#   (1675, 1),
#   (1676, 1),
#   (1677, 1),
#   (1678, 1),
#   (1679, 5),
#   (1680, 4),
#   (1681, 3),
#   (1682, 2),
#   (1683, 2),
#   (1684, 1),
#   (1685, 1),
#   (1686, 1),
#   (1687, 1),
#   (1688, 1),
#   (1689, 1),
#   (1690, 1),
#   (1691, 1),
#   (1692, 2),
#   (1693, 1),
#   (1694, 1),
#   (1695, 1),
#   (1696, 1),
#   (1697, 1),
#   (1698, 1),
#   (1699, 1),
#   (1700, 1),
#   (1701, 1)],
#  [(0, 5),
#   (8, 4),
#   (9, 2),
#   (15, 1),
#   (27, 2),
#   (32, 1),
#   (34, 1),
#   (40, 7),
#   (52, 4),
#   (68, 13),
#   (84, 1),
#   (87, 2),
#   (88, 1),
#   (91, 1),
#   (114, 2),
#   (115, 2),
#   (126, 2),
#   (134, 1),
#   (150, 1),
#   (158, 2),
#   (163, 3),
#   (168, 6),
#   (172, 4),
#   (174, 1),
#   (181, 1),
#   (182, 1),
#   (186, 1),
#   (187, 1),
#   (193, 1),
#   (196, 1),
#   (216, 5),
#   (233, 1),
#   (241, 1),
#   (243, 1),
#   (257, 1),
#   (269, 1),
#   (272, 1),
#   (275, 1),
#   (295, 1),
#   (302, 7),
#   (307, 1),
#   (329, 1),
#   (355, 1),
#   (364, 1),
#   (388, 1),
#   (393, 1),
#   (400, 1),
#   (427, 2),
#   (446, 1),
#   (448, 1),
#   (490, 1),
#   (500, 2),
#   (507, 1),
#   (528, 1),
#   (539, 1),
#   (540, 1),
#   (562, 1),
#   (580, 1),
#   (581, 1),
#   (619, 1),
#   (640, 1),
#   (660, 1),
#   (667, 1),
#   (669, 1),
#   (697, 1),
#   (709, 1),
#   (722, 1),
#   (726, 1),
#   (773, 1),
#   (812, 1),
#   (926, 1),
#   (940, 1),
#   (965, 1),
#   (1028, 1),
#   (1083, 1),
#   (1142, 1),
#   (1182, 1),
#   (1554, 1),
#   (1690, 2),
#   (1702, 1),
#   (1703, 2),
#   (1704, 1),
#   (1705, 1),
#   (1706, 1),
#   (1707, 1),
#   (1708, 1),
#   (1709, 1),
#   (1710, 1),
#   (1711, 1),
#   (1712, 1),
#   (1713, 1),
#   (1714, 4),
#   (1715, 1),
#   (1716, 1),
#   (1717, 1),
#   (1718, 1),
#   (1719, 1),
#   (1720, 1),
#   (1721, 1),
#   (1722, 1),
#   (1723, 1),
#   (1724, 1),
#   (1725, 1),
#   (1726, 1),
#   (1727, 2),
#   (1728, 1),
#   (1729, 1),
#   (1730, 1),
#   (1731, 2),
#   (1732, 1),
#   (1733, 1),
#   (1734, 1),
#   (1735, 2),
#   (1736, 1),
#   (1737, 1),
#   (1738, 1),
#   (1739, 1)],
#  [(0, 1),
#   (3, 9),
#   (8, 2),
#   (9, 4),
#   (12, 1),
#   (15, 1),
#   (21, 2),
#   (27, 7),
#   (34, 3),
#   (41, 1),
#   (50, 1),
#   (54, 2),
#   (59, 1),
#   (60, 5),
#   (68, 13),
#   (74, 1),
#   (85, 1),
#   (86, 1),
#   (87, 2),
#   (91, 1),
#   (110, 4),
#   (111, 2),
#   (114, 4),
#   (118, 1),
#   (126, 1),
#   (127, 4),
#   (129, 1),
#   (134, 1),
#   (162, 1),
#   (163, 3),
#   (166, 1),
#   (168, 7),
#   (171, 1),
#   (172, 7),
#   (182, 1),
#   (186, 1),
#   (196, 1),
#   (205, 1),
#   (210, 2),
#   (213, 1),
#   (231, 1),
#   (237, 2),
#   (241, 1),
#   (247, 4),
#   (259, 2),
#   (268, 2),
#   (289, 1),
#   (291, 1),
#   (304, 5),
#   (322, 1),
#   (326, 1),
#   (355, 3),
#   (356, 1),
#   (359, 1),
#   (361, 1),
#   (372, 1),
#   (381, 1),
#   (387, 4),
#   (404, 1),
#   (414, 1),
#   (421, 6),
#   (426, 1),
#   (437, 1),
#   (448, 1),
#   (454, 1),
#   (456, 1),
#   (474, 2),
#   (478, 1),
#   (479, 1),
#   (483, 5),
#   (484, 2),
#   (561, 2),
#   (581, 3),
#   (582, 1),
#   (615, 7),
#   (632, 1),
#   (642, 1),
#   (653, 2),
#   (655, 1),
#   (664, 12),
#   (677, 2),
#   (684, 1),
#   (689, 1),
#   (692, 1),
#   (758, 1),
#   (845, 1),
#   (856, 3),
#   (860, 1),
#   (926, 1),
#   (941, 3),
#   (951, 1),
#   (963, 1),
#   (1010, 1),
#   (1026, 2),
#   (1033, 1),
#   (1052, 9),
#   (1053, 1),
#   (1102, 1),
#   (1129, 1),
#   (1214, 1),
#   (1236, 1),
#   (1242, 1),
#   (1287, 4),
#   (1311, 1),
#   (1319, 1),
#   (1321, 2),
#   (1332, 1),
#   (1357, 1),
#   (1418, 4),
#   (1420, 2),
#   (1428, 1),
#   (1452, 1),
#   (1465, 1),
#   (1472, 1),
#   (1473, 1),
#   (1475, 1),
#   (1476, 3),
#   (1491, 1),
#   (1504, 1),
#   (1562, 9),
#   (1564, 2),
#   (1579, 1),
#   (1616, 3),
#   (1689, 1),
#   (1733, 1),
#   (1740, 1),
#   (1741, 1),
#   (1742, 1),
#   (1743, 1),
#   (1744, 1),
#   (1745, 1),
#   (1746, 1),
#   (1747, 1),
#   (1748, 1),
#   (1749, 1),
#   (1750, 5),
#   (1751, 1),
#   (1752, 1),
#   (1753, 1),
#   (1754, 1),
#   (1755, 1),
#   (1756, 1),
#   (1757, 1),
#   (1758, 1),
#   (1759, 1),
#   (1760, 2),
#   (1761, 1),
#   (1762, 1),
#   (1763, 1),
#   (1764, 1),
#   (1765, 1),
#   (1766, 1),
#   (1767, 2),
#   (1768, 1),
#   (1769, 1),
#   (1770, 2),
#   (1771, 1),
#   (1772, 1),
#   (1773, 1),
#   (1774, 1),
#   (1775, 2),
#   (1776, 1),
#   (1777, 1),
#   (1778, 1),
#   (1779, 1),
#   (1780, 1),
#   (1781, 2),
#   (1782, 1),
#   (1783, 2),
#   (1784, 1),
#   (1785, 1),
#   (1786, 1),
#   (1787, 1),
#   (1788, 1),
#   (1789, 1),
#   (1790, 1),
#   (1791, 2),
#   (1792, 1),
#   (1793, 2),
#   (1794, 1),
#   (1795, 5),
#   (1796, 1),
#   (1797, 1),
#   (1798, 2),
#   (1799, 2),
#   (1800, 2),
#   (1801, 1),
#   (1802, 1),
#   (1803, 1),
#   (1804, 1),
#   (1805, 2),
#   (1806, 1),
#   (1807, 1),
#   (1808, 1),
#   (1809, 1),
#   (1810, 2),
#   (1811, 1),
#   (1812, 1),
#   (1813, 1),
#   (1814, 1),
#   (1815, 3),
#   (1816, 1),
#   (1817, 2),
#   (1818, 1),
#   (1819, 1),
#   (1820, 1),
#   (1821, 1),
#   (1822, 1),
#   (1823, 1),
#   (1824, 1)],
#  [(0, 4),
#   (3, 1),
#   (27, 2),
#   (34, 1),
#   (52, 1),
#   (54, 1),
#   (57, 1),
#   (68, 6),
#   (91, 8),
#   (93, 1),
#   (97, 2),
#   (99, 3),
#   (115, 1),
#   (134, 2),
#   (135, 5),
#   (157, 1),
#   (158, 2),
#   (168, 8),
#   (201, 1),
#   (209, 1),
#   (212, 1),
#   (216, 1),
#   (232, 1),
#   (241, 1),
#   (257, 1),
#   (265, 2),
#   (272, 1),
#   (275, 1),
#   (297, 1),
#   (302, 1),
#   (322, 1),
#   (329, 1),
#   (355, 1),
#   (373, 1),
#   (518, 1),
#   (538, 1),
#   (545, 1),
#   (557, 1),
#   (595, 1),
#   (611, 1),
#   (647, 1),
#   (664, 1),
#   (687, 1),
#   (744, 1),
#   (763, 1),
#   (768, 1),
#   (776, 1),
#   (818, 1),
#   (826, 1),
#   (961, 2),
#   (1050, 1),
#   (1101, 1),
#   (1167, 1),
#   (1192, 1),
#   (1247, 1),
#   (1292, 1),
#   (1367, 1),
#   (1725, 1),
#   (1825, 1),
#   (1826, 1),
#   (1827, 1),
#   (1828, 1),
#   (1829, 1),
#   (1830, 3),
#   (1831, 1),
#   (1832, 1),
#   (1833, 1),
#   (1834, 1),
#   (1835, 2),
#   (1836, 1),
#   (1837, 2),
#   (1838, 1),
#   (1839, 1),
#   (1840, 1),
#   (1841, 1),
#   (1842, 1),
#   (1843, 1)],
#  [(0, 4),
#   (8, 1),
#   (44, 1),
#   (65, 1),
#   (68, 3),
#   (81, 1),
#   (91, 1),
#   (92, 1),
#   (93, 1),
#   (130, 1),
#   (148, 1),
#   (158, 2),
#   (168, 1),
#   (180, 1),
#   (209, 1),
#   (210, 1),
#   (223, 1),
#   (245, 1),
#   (269, 1),
#   (272, 2),
#   (275, 1),
#   (364, 1),
#   (373, 2),
#   (393, 1),
#   (395, 1),
#   (479, 1),
#   (518, 1),
#   (571, 1),
#   (684, 1),
#   (696, 1),
#   (824, 1),
#   (965, 1),
#   (1357, 1),
#   (1617, 1),
#   (1626, 1),
#   (1714, 1),
#   (1818, 1),
#   (1844, 1),
#   (1845, 1),
#   (1846, 1),
#   (1847, 1),
#   (1848, 1),
#   (1849, 1),
#   (1850, 1),
#   (1851, 1),
#   (1852, 1),
#   (1853, 1),
#   (1854, 1),
#   (1855, 1),
#   (1856, 1),
#   (1857, 1)],
#  [(0, 3),
#   (2, 1),
#   (3, 7),
#   (7, 1),
#   (8, 6),
#   (9, 7),
#   (13, 1),
#   (26, 1),
#   (27, 2),
#   (31, 2),
#   (32, 1),
#   (34, 2),
#   (40, 1),
#   (47, 6),
#   (48, 6),
#   (51, 2),
#   (52, 9),
#   (55, 1),
#   (56, 1),
#   (58, 4),
#   (60, 1),
#   (68, 26),
#   (72, 3),
#   (81, 1),
#   (87, 5),
#   (91, 3),
#   (92, 1),
#   (105, 1),
#   (114, 1),
#   (115, 1),
#   (117, 3),
#   (120, 2),
#   (123, 2),
#   (132, 1),
#   (134, 2),
#   (140, 2),
#   (146, 1),
#   (148, 4),
#   (157, 1),
#   (158, 1),
#   (162, 1),
#   (168, 5),
#   (172, 3),
#   (183, 2),
#   (199, 1),
#   (204, 1),
#   (215, 1),
#   (229, 2),
#   (247, 4),
#   (251, 1),
#   (265, 1),
#   (268, 1),
#   (275, 1),
#   (279, 1),
#   (290, 1),
#   (294, 1),
#   (302, 1),
#   (307, 2),
#   (308, 3),
#   (348, 1),
#   (355, 2),
#   (358, 2),
#   (360, 1),
#   (367, 1),
#   (378, 2),
#   (415, 2),
#   (423, 1),
#   (424, 2),
#   (441, 1),
#   (474, 1),
#   (478, 1),
#   (479, 2),
#   (484, 1),
#   (488, 1),
#   (491, 3),
#   (511, 1),
#   (522, 1),
#   (566, 1),
#   (580, 1),
#   (602, 1),
#   (619, 1),
#   (637, 1),
#   (644, 1),
#   (646, 3),
#   (650, 2),
#   (653, 2),
#   (660, 1),
#   (664, 16),
#   (667, 2),
#   (669, 1),
#   (672, 1),
#   (702, 1),
#   (704, 1),
#   (709, 3),
#   (710, 8),
#   (734, 1),
#   (746, 1),
#   (748, 1),
#   (773, 4),
#   (775, 2),
#   (784, 1),
#   (785, 1),
#   (790, 1),
#   (803, 1),
#   (808, 1),
#   (811, 1),
#   (824, 1),
#   (839, 1),
#   (865, 1),
#   (890, 3),
#   (909, 1),
#   (918, 1),
#   (926, 1),
#   (940, 1),
#   (945, 1),
#   (951, 1),
#   (962, 1),
#   (1027, 1),
#   (1043, 2),
#   (1076, 1),
#   (1102, 1),
#   (1147, 1),
#   (1151, 1),
#   (1161, 4),
#   (1202, 2),
#   (1206, 1),
#   (1233, 1),
#   (1241, 1),
#   (1273, 1),
#   (1286, 1),
#   (1304, 2),
#   (1327, 3),
#   (1350, 1),
#   (1478, 1),
#   (1518, 1),
#   (1567, 1),
#   (1607, 1),
#   (1626, 1),
#   (1721, 4),
#   (1722, 2),
#   (1723, 1),
#   (1793, 2),
#   (1858, 1),
#   (1859, 1),
#   (1860, 1),
#   (1861, 1),
#   (1862, 1),
#   (1863, 1),
#   (1864, 3),
#   (1865, 1),
#   (1866, 1),
#   (1867, 1),
#   (1868, 1),
#   (1869, 1),
#   (1870, 1),
#   (1871, 1),
#   (1872, 1),
#   (1873, 2),
#   (1874, 1),
#   (1875, 1),
#   (1876, 3),
#   (1877, 1),
#   (1878, 1),
#   (1879, 1),
#   (1880, 1),
#   (1881, 1),
#   (1882, 1),
#   (1883, 3),
#   (1884, 3),
#   (1885, 1),
#   (1886, 1),
#   (1887, 2),
#   (1888, 2),
#   (1889, 1),
# ...
#   (1181, 2),
#   (1402, 1),
#   (1468, 1),
#   (1498, 1),
#   (1660, 1),
#   (1726, 1),
#   (1793, 1),
#   (1864, 1),
#   (2001, 1),
#   (2067, 1),
#   (2078, 1),
#   (2106, 1),
#   (2149, 1),
#   (2282, 1),
#   (2334, 1),
#   (2364, 1),
#   (2370, 1),
#   (2537, 2),
#   (2557, 2),
#   (2589, 1),
#   (2606, 1),
#   (2744, 1),
#   (2746, 6),
#   (2749, 1),
#   (2758, 2),
#   (2762, 1),
#   (2766, 1),
#   (2769, 1),
#   (2770, 1),
#   (2825, 1),
#   (2908, 1),
#   (2909, 1)],
#  [(19, 1),
#   (22, 1),
#   (27, 7),
#   (30, 2),
#   (34, 1),
#   (71, 2),
#   (87, 1),
#   (161, 1),
#   (163, 1),
#   (247, 3),
#   (268, 3),
#   (269, 2),
#   (292, 1),
#   (298, 1),
#   (305, 2),
#   (363, 6),
#   (414, 1),
#   (446, 1),
#   (476, 1),
#   (646, 1),
#   (659, 1),
#   (692, 1),
#   (851, 1),
#   (892, 4),
#   (966, 1),
#   (1025, 7),
#   (1192, 1),
#   (1247, 3),
#   (1763, 1),
#   (1845, 1),
#   (1903, 1),
#   (1949, 1),
#   (2072, 2),
#   (2129, 1),
#   (2506, 1),
#   (2793, 1),
#   (2892, 1),
#   (2893, 3),
#   (2894, 1),
#   (2895, 1),
#   (2896, 2),
#   (2897, 1),
#   (2898, 1),
#   (2901, 1),
#   (2902, 1),
#   (2904, 1),
#   (2905, 2),
#   (2906, 1),
#   (2910, 1),
#   (2911, 1),
#   (2912, 1),
#   (2913, 1)],
#  [(27, 8),
#   (71, 1),
#   (87, 1),
#   (88, 1),
#   (129, 1),
#   (163, 1),
#   (247, 6),
#   (268, 2),
#   (269, 1),
#   (275, 1),
#   (292, 1),
#   (298, 1),
#   (305, 1),
#   (363, 2),
#   (692, 1),
#   (851, 1),
#   (892, 2),
#   (1025, 4),
#   (1192, 1),
#   (1247, 1),
#   (1626, 1),
#   (1903, 3),
#   (2072, 1),
#   (2129, 1),
#   (2488, 1),
#   (2893, 2),
#   (2896, 3),
#   (2899, 1),
#   (2902, 1),
#   (2905, 1),
#   (2910, 1),
#   (2912, 1)],
#  [(19, 1),
#   (27, 7),
#   (34, 1),
#   (41, 1),
#   (71, 1),
#   (152, 1),
#   (241, 1),
#   (247, 1),
#   (259, 2),
#   (363, 1),
#   (378, 1),
#   (387, 1),
#   (456, 1),
#   (474, 1),
#   (538, 1),
#   (548, 1),
#   (586, 8),
#   (588, 3),
#   (632, 1),
#   (650, 2),
#   (660, 1),
#   (679, 1),
#   (704, 1),
#   (798, 1),
#   (871, 2),
#   (881, 1),
#   (953, 1),
#   (972, 1),
#   (1025, 4),
#   (1256, 1),
#   (1405, 1),
#   (1801, 1),
#   (1817, 1),
#   (2067, 6),
#   (2090, 3),
#   (2216, 1),
#   (2374, 1),
#   (2462, 2),
#   (2682, 1),
#   (2848, 1),
#   (2849, 1),
#   (2914, 1),
#   (2915, 1),
#   (2916, 1),
#   (2917, 1),
#   (2918, 1),
#   (2919, 1)],
#  [(2, 1),
#   (5, 1),
#   (15, 1),
#   (27, 9),
#   (31, 2),
#   (34, 2),
#   (38, 1),
#   (55, 1),
#   (58, 1),
#   (71, 1),
#   (74, 2),
#   (87, 3),
#   (105, 1),
#   (120, 1),
#   (140, 1),
#   (174, 6),
#   (176, 5),
#   (179, 1),
#   (197, 1),
#   (214, 1),
#   (241, 2),
#   (245, 1),
#   (247, 7),
#   (259, 1),
#   (269, 1),
#   (273, 1),
#   (283, 1),
#   (291, 1),
#   (307, 1),
#   (317, 1),
#   (322, 2),
#   (335, 1),
#   (357, 1),
#   (364, 2),
#   (378, 3),
#   (424, 1),
#   (441, 2),
#   (447, 1),
#   (474, 2),
#   (476, 1),
#   (479, 3),
#   (484, 5),
#   (491, 1),
#   (516, 3),
#   (520, 1),
#   (538, 2),
#   (546, 1),
#   (568, 1),
#   (594, 3),
#   (619, 3),
#   (637, 2),
#   (659, 1),
#   (660, 1),
#   (664, 1),
#   (666, 1),
#   (700, 1),
#   (735, 1),
#   (758, 8),
#   (784, 2),
#   (796, 1),
#   (935, 1),
#   (1025, 17),
#   (1043, 1),
#   (1051, 1),
#   (1055, 1),
#   (1075, 1),
#   (1129, 1),
#   (1146, 1),
#   (1159, 1),
#   (1184, 1),
#   (1192, 1),
#   (1211, 1),
#   (1229, 2),
#   (1292, 1),
#   (1327, 2),
#   (1343, 1),
#   (1367, 1),
#   (1393, 3),
#   (1519, 1),
#   (1548, 1),
#   (1563, 1),
#   (1636, 1),
#   (1659, 1),
#   (1729, 1),
#   (1759, 1),
#   (1801, 1),
#   (1891, 1),
#   (1928, 1),
#   (2159, 1),
#   (2207, 1),
#   (2274, 1),
#   (2331, 1),
#   (2343, 1),
#   (2379, 1),
#   (2383, 1),
#   (2403, 1),
#   (2418, 1),
#   (2469, 1),
#   (2502, 1),
#   (2555, 1),
#   (2703, 2),
#   (2754, 2),
#   (2759, 1),
#   (2785, 1),
#   (2850, 1),
#   (2870, 1),
#   (2913, 1),
#   (2920, 6),
#   (2921, 1),
#   (2922, 1),
#   (2923, 1),
#   (2924, 1),
#   (2925, 1),
#   (2926, 1),
#   (2927, 1),
#   (2928, 1),
#   (2929, 1),
#   (2930, 1),
#   (2931, 1),
#   (2932, 1),
#   (2933, 1),
#   (2934, 1),
#   (2935, 1)],
#  [(2, 5),
#   (15, 3),
#   (19, 1),
#   (22, 1),
#   (27, 16),
#   (34, 1),
#   (41, 1),
#   (57, 1),
#   (63, 2),
#   (71, 6),
#   (85, 2),
#   (87, 7),
#   (113, 1),
#   (118, 1),
#   (120, 4),
#   (140, 1),
#   (142, 1),
#   (161, 1),
#   (162, 2),
#   (182, 1),
#   (193, 1),
#   (196, 1),
#   (205, 2),
#   (232, 1),
#   (233, 1),
#   (241, 3),
#   (242, 3),
#   (245, 3),
#   (247, 1),
#   (251, 2),
#   (259, 14),
#   (268, 1),
#   (279, 1),
#   (296, 1),
#   (309, 1),
#   (360, 2),
#   (363, 3),
#   (373, 2),
#   (374, 1),
#   (378, 1),
#   (381, 1),
#   (387, 4),
#   (441, 1),
#   (448, 3),
#   (456, 5),
#   (474, 1),
#   (479, 1),
#   (487, 1),
#   (503, 1),
#   (516, 1),
#   (546, 3),
#   (586, 1),
#   (588, 2),
#   (589, 1),
#   (602, 1),
#   (627, 1),
#   (653, 1),
#   (659, 1),
#   (660, 2),
#   (664, 2),
#   (666, 1),
#   (667, 1),
#   (679, 2),
#   (687, 1),
#   (705, 1),
#   (733, 1),
#   (743, 1),
#   (758, 1),
#   (761, 1),
#   (770, 1),
#   (773, 2),
#   (778, 1),
#   (791, 1),
#   (796, 2),
#   (914, 2),
#   (918, 1),
#   (935, 2),
#   (961, 1),
#   (1025, 26),
#   (1028, 1),
#   (1031, 1),
#   (1061, 2),
#   (1073, 3),
#   (1075, 1),
#   (1080, 1),
#   (1101, 2),
#   (1112, 3),
#   (1227, 1),
#   (1343, 1),
#   (1357, 1),
#   (1367, 2),
#   (1416, 2),
#   (1567, 1),
#   (1596, 1),
#   (1600, 1),
#   (1616, 3),
#   (1629, 1),
#   (1660, 6),
#   (1661, 1),
#   (1664, 4),
#   (1763, 1),
#   (1770, 1),
#   (1799, 1),
#   (1817, 1),
#   (1825, 5),
#   (1869, 3),
#   (1911, 1),
#   (1932, 1),
#   (1941, 1),
#   (1954, 3),
#   (1985, 1),
#   (1995, 1),
#   (2010, 1),
#   (2013, 1),
#   (2041, 2),
#   (2067, 21),
#   (2086, 5),
#   (2154, 1),
#   (2334, 1),
#   (2343, 1),
#   (2374, 7),
#   (2462, 5),
#   (2463, 1),
#   (2476, 1),
#   (2496, 1),
#   (2532, 1),
#   (2538, 1),
#   (2573, 3),
#   (2577, 1),
#   (2624, 1),
#   (2698, 2),
#   (2757, 2),
#   (2834, 1),
#   (2836, 1),
#   (2849, 4),
#   (2862, 1),
#   (2871, 1),
#   (2889, 1),
#   (2897, 3),
#   (2910, 1),
#   (2912, 1),
#   (2936, 2),
#   (2937, 1),
#   (2938, 1),
#   (2939, 1),
#   (2940, 1),
#   (2941, 4),
#   (2942, 1),
#   (2943, 2),
#   (2944, 1),
#   (2945, 1),
#   (2946, 1),
#   (2947, 1),
#   (2948, 2),
#   (2949, 2),
#   (2950, 1),
#   (2951, 1),
#   (2952, 1),
#   (2953, 1),
#   (2954, 2),
#   (2955, 1),
#   (2956, 2),
#   (2957, 8),
#   (2958, 1),
#   (2959, 1),
#   (2960, 3),
#   (2961, 2),
#   (2962, 1),
#   (2963, 1),
#   (2964, 3),
#   (2965, 1),
#   (2966, 1),
#   (2967, 1),
#   (2968, 2),
#   (2969, 2),
#   (2970, 1),
#   (2971, 1),
#   (2972, 1)],
#  [(19, 1),
#   (22, 4),
#   (27, 10),
#   (28, 1),
#   (34, 1),
#   (41, 1),
#   (46, 1),
#   (50, 1),
#   (71, 2),
#   (74, 1),
#   (82, 1),
#   (87, 1),
#   (88, 3),
#   (162, 1),
#   (163, 1),
#   (247, 2),
#   (251, 1),
#   (256, 1),
#   (259, 4),
#   (269, 1),
#   (274, 1),
#   (289, 1),
#   (308, 1),
#   (339, 1),
#   (363, 1),
#   (380, 1),
#   (387, 1),
#   (424, 1),
#   (432, 1),
#   (437, 1),
#   (448, 1),
#   (456, 1),
#   (479, 2),
#   (523, 1),
#   (555, 1),
#   (589, 2),
#   (592, 1),
#   (616, 1),
#   (656, 1),
#   (660, 3),
#   (664, 4),
#   (667, 6),
#   (692, 1),
#   (709, 1),
#   (733, 1),
#   (821, 2),
#   (830, 1),
#   (881, 1),
#   (896, 1),
#   (910, 1),
#   (914, 1),
#   (935, 1),
#   (953, 1),
#   (1025, 13),
#   (1029, 1),
#   (1033, 1),
#   (1080, 2),
#   (1142, 1),
#   (1185, 1),
#   (1252, 1),
#   (1256, 1),
#   (1273, 4),
#   (1357, 1),
#   (1367, 2),
#   (1405, 1),
#   (1558, 1),
#   (1567, 1),
#   (1629, 1),
#   (1726, 1),
#   (1731, 1),
#   (1801, 2),
#   (2010, 1),
#   (2067, 10),
#   (2069, 2),
#   (2097, 1),
#   (2146, 1),
#   (2147, 1),
#   (2216, 1),
#   (2362, 1),
#   (2374, 2),
#   (2390, 1),
#   (2420, 2),
#   (2451, 3),
#   (2458, 1),
#   (2462, 5),
#   (2478, 1),
#   (2486, 1),
#   (2572, 1),
#   (2656, 4),
#   (2751, 2),
#   (2761, 1),
#   (2810, 1),
#   (2834, 1),
#   (2847, 1),
#   (2848, 1),
#   (2862, 1),
#   (2882, 2),
#   (2937, 2),
#   (2957, 7),
#   (2960, 6),
#   (2968, 2),
#   (2973, 1),
#   (2974, 2),
#   (2975, 1),
#   (2976, 1),
#   (2977, 1),
#   (2978, 1),
#   (2979, 1),
#   (2980, 1),
#   (2981, 1),
#   (2982, 1),
#   (2983, 1),
#   (2984, 3),
#   (2985, 1),
#   (2986, 1),
#   (2987, 1),
#   (2988, 1),
#   (2989, 2),
#   (2990, 1),
#   (2991, 1)],
#  [(2, 2),
#   (19, 1),
#   (22, 1),
#   (27, 10),
#   (34, 1),
#   (39, 2),
#   (41, 2),
#   (45, 1),
#   (71, 1),
#   (87, 2),
#   (88, 2),
#   (116, 1),
#   (132, 1),
#   (163, 4),
#   (181, 1),
#   (187, 1),
#   (238, 1),
#   (241, 1),
#   (242, 5),
#   (245, 1),
#   (247, 6),
#   (251, 2),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (300, 1),
#   (304, 2),
#   (307, 1),
#   (326, 1),
#   (345, 11),
#   (355, 1),
#   (363, 1),
#   (373, 1),
#   (387, 1),
#   (456, 2),
#   (474, 1),
#   (504, 1),
#   (520, 2),
#   (538, 1),
#   (592, 2),
#   (610, 1),
#   (642, 1),
#   (660, 3),
#   (667, 4),
#   (704, 1),
#   (748, 1),
#   (758, 1),
#   (801, 1),
#   (914, 1),
#   (1025, 13),
#   (1026, 1),
#   (1034, 1),
#   (1080, 1),
#   (1101, 1),
#   (1202, 1),
#   (1273, 1),
#   (1393, 1),
#   (1558, 1),
#   (1629, 2),
#   (1660, 1),
#   (1770, 2),
#   (1801, 1),
#   (1871, 2),
#   (1939, 1),
#   (1985, 3),
#   (2001, 1),
#   (2067, 6),
#   (2069, 1),
#   (2086, 2),
#   (2090, 2),
#   (2133, 1),
#   (2325, 1),
#   (2362, 1),
#   (2410, 1),
#   (2429, 1),
#   (2436, 1),
#   (2462, 2),
#   (2505, 1),
#   (2532, 2),
#   (2556, 1),
#   (2736, 1),
#   (2757, 1),
#   (2770, 1),
#   (2828, 2),
#   (2836, 1),
#   (2847, 1),
#   (2848, 1),
#   (2849, 1),
#   (2850, 1),
#   (2856, 2),
#   (2871, 1),
#   (2957, 4),
#   (2960, 5),
#   (2966, 1),
#   (2968, 4),
#   (2992, 1),
#   (2993, 1),
#   (2994, 1),
#   (2995, 1),
#   (2996, 1),
#   (2997, 1)],
#  [(22, 1),
#   (27, 5),
#   (30, 2),
#   (34, 1),
#   (42, 1),
#   (71, 2),
#   (87, 1),
#   (88, 1),
#   (163, 1),
#   (182, 1),
#   (193, 1),
#   (196, 1),
#   (199, 1),
#   (232, 1),
#   (233, 1),
#   (245, 1),
#   (247, 4),
#   (268, 1),
#   (269, 1),
#   (360, 1),
#   (363, 2),
#   (456, 1),
#   (476, 1),
#   (592, 1),
#   (692, 1),
#   (773, 2),
#   (892, 2),
#   (966, 1),
#   (1010, 1),
#   (1025, 8),
#   (1168, 2),
#   (1190, 1),
#   (1201, 1),
#   (1211, 1),
#   (1247, 4),
#   (1466, 1),
#   (1579, 1),
#   (1596, 1),
#   (1763, 1),
#   (1845, 1),
#   (1903, 1),
#   (1906, 1),
#   (1932, 1),
#   (2067, 4),
#   (2488, 1),
#   (2522, 1),
#   (2532, 1),
#   (2624, 1),
#   (2671, 1),
#   (2679, 1),
#   (2793, 1),
#   (2892, 1),
#   (2893, 4),
#   (2895, 1),
#   (2896, 3),
#   (2899, 1),
#   (2900, 1),
#   (2901, 1),
#   (2902, 1),
#   (2905, 1),
#   (2911, 1),
#   (2957, 1),
#   (2998, 1),
#   (2999, 1),
#   (3000, 1),
#   (3001, 1)],
#  [(8, 4),
#   (15, 1),
#   (22, 1),
#   (26, 1),
#   (27, 9),
#   (30, 2),
#   (34, 1),
#   (39, 1),
#   (108, 2),
#   (163, 1),
#   (216, 1),
#   (247, 4),
#   (259, 1),
#   (268, 1),
#   (291, 1),
#   (298, 1),
#   (305, 2),
#   (360, 1),
#   (431, 1),
#   (446, 1),
#   (476, 1),
#   (483, 1),
#   (548, 1),
#   (592, 1),
#   (650, 1),
#   (659, 1),
#   (664, 1),
#   (692, 1),
#   (746, 2),
#   (892, 1),
#   (966, 1),
#   (1025, 7),
#   (1053, 4),
#   (1082, 1),
#   (1168, 1),
#   (1201, 1),
#   (1222, 1),
#   (1247, 6),
#   (1466, 1),
#   (1567, 1),
#   (1660, 1),
#   (1763, 1),
#   (1845, 1),
#   (1903, 2),
#   (2001, 1),
#   (2067, 1),
#   (2072, 1),
#   (2129, 3),
#   (2714, 1),
#   (2793, 1),
#   (2892, 1),
#   (2893, 5),
#   (2894, 1),
#   (2895, 1),
#   (2896, 2),
#   (2897, 1),
#   (2898, 1),
#   (2901, 1),
#   (2902, 1),
#   (2904, 1),
#   (2905, 1),
#   (2906, 1),
#   (3002, 2),
#   (3003, 1),
#   (3004, 1),
#   (3005, 1),
#   (3006, 1)],
#  [(3, 1),
#   (4, 2),
#   (8, 2),
#   (11, 1),
#   (15, 6),
#   (27, 10),
#   (30, 1),
#   (34, 1),
#   (41, 6),
#   (54, 1),
#   (71, 6),
#   (72, 2),
#   (88, 1),
#   (99, 2),
#   (110, 2),
#   (111, 1),
#   (113, 1),
#   (120, 6),
#   (129, 1),
#   (132, 2),
#   (147, 1),
#   (152, 6),
#   (161, 1),
#   (162, 1),
#   (169, 2),
#   (182, 2),
#   (231, 1),
#   (232, 2),
#   (247, 2),
#   (259, 1),
#   (266, 2),
#   (268, 4),
#   (273, 3),
#   (287, 1),
#   (327, 1),
#   (329, 2),
#   (355, 1),
#   (358, 5),
#   (359, 1),
#   (360, 4),
#   (378, 1),
#   (381, 2),
#   (414, 1),
#   (415, 3),
#   (456, 7),
#   (458, 4),
#   (474, 1),
#   (511, 2),
#   (538, 1),
#   (551, 1),
#   (561, 7),
#   (589, 3),
#   (594, 2),
#   (602, 2),
#   (646, 1),
#   (647, 1),
#   (664, 7),
#   (677, 1),
#   (679, 1),
#   (692, 2),
#   (704, 6),
#   (730, 1),
#   (733, 1),
#   (758, 1),
#   (873, 1),
#   (881, 2),
#   (1025, 33),
#   (1028, 1),
#   (1073, 4),
#   (1075, 1),
#   (1091, 1),
#   (1096, 1),
#   (1112, 2),
#   (1184, 1),
#   (1194, 11),
#   (1202, 1),
#   (1212, 1),
#   (1222, 2),
#   (1233, 7),
#   (1263, 1),
#   (1268, 1),
#   (1357, 5),
#   (1377, 8),
#   (1416, 2),
#   (1498, 1),
#   (1649, 1),
#   (1659, 4),
#   (1689, 1),
#   (1704, 1),
#   (1774, 1),
#   (1840, 1),
#   (1884, 1),
#   (1903, 1),
#   (1911, 1),
#   (1998, 1),
#   (2037, 1),
#   (2043, 6),
#   (2101, 1),
#   (2105, 1),
#   (2154, 3),
#   (2159, 1),
#   (2165, 2),
#   (2213, 1),
#   (2331, 1),
#   (2370, 1),
#   (2391, 2),
#   (2406, 1),
#   (2425, 1),
#   (2433, 1),
#   (2471, 3),
#   (2496, 1),
#   (2502, 3),
#   (2508, 1),
#   (2516, 1),
#   (2546, 2),
#   (2556, 1),
#   (2584, 1),
#   (2601, 1),
#   (2728, 1),
#   (2850, 10),
#   (3007, 1),
#   (3008, 3),
#   (3009, 1),
#   (3010, 32),
#   (3011, 3),
#   (3012, 1),
#   (3013, 1),
#   (3014, 1),
#   (3015, 1),
#   (3016, 2),
#   (3017, 6),
#   (3018, 4),
#   (3019, 1),
#   (3020, 3),
#   (3021, 1),
#   (3022, 1),
#   (3023, 1),
#   (3024, 1),
#   (3025, 1),
#   (3026, 5),
#   (3027, 1),
#   (3028, 2),
#   (3029, 1),
#   (3030, 1),
#   (3031, 1),
#   (3032, 1)],
#  [(15, 1),
#   (17, 1),
#   (19, 2),
#   (22, 1),
#   (26, 1),
#   (27, 12),
#   (30, 2),
#   (31, 1),
#   (34, 1),
#   (39, 1),
#   (41, 1),
#   (45, 2),
#   (50, 1),
#   (55, 1),
#   (71, 5),
#   (87, 2),
#   (88, 3),
#   (99, 1),
#   (119, 1),
#   (126, 1),
#   (129, 2),
#   (132, 3),
#   (169, 1),
#   (173, 2),
#   (182, 1),
#   (193, 1),
#   (196, 1),
#   (233, 1),
#   (238, 2),
#   (241, 2),
#   (242, 2),
#   (247, 1),
#   (251, 4),
#   (256, 2),
#   (259, 1),
#   (267, 2),
#   (300, 1),
#   (304, 2),
#   (307, 1),
#   (353, 1),
#   (359, 3),
#   (360, 1),
#   (363, 1),
#   (367, 1),
#   (368, 1),
#   (467, 1),
#   (475, 1),
#   (476, 1),
#   (483, 2),
#   (520, 1),
#   (523, 1),
#   (548, 1),
#   (551, 1),
#   (552, 1),
#   (561, 1),
#   (562, 1),
#   (591, 2),
#   (592, 1),
#   (615, 1),
#   (619, 1),
#   (627, 1),
#   (650, 2),
#   (660, 7),
#   (664, 6),
#   (667, 1),
#   (679, 1),
#   (692, 1),
#   (709, 1),
#   (812, 1),
#   (890, 1),
#   (914, 3),
#   (941, 1),
#   (953, 1),
#   (972, 1),
#   (1011, 1),
#   (1025, 15),
#   (1029, 1),
#   (1031, 1),
#   (1033, 1),
#   (1061, 1),
#   (1080, 1),
#   (1142, 1),
#   (1159, 1),
#   (1185, 1),
#   (1192, 1),
#   (1212, 2),
#   (1228, 1),
#   (1247, 1),
#   (1252, 2),
#   (1263, 1),
#   (1273, 3),
#   (1319, 1),
#   (1338, 1),
#   (1357, 1),
#   (1416, 3),
#   (1418, 1),
#   (1558, 1),
#   (1596, 1),
#   (1662, 1),
#   (1731, 1),
#   (1825, 1),
#   (1840, 1),
#   (1954, 1),
#   (2010, 2),
#   (2041, 1),
#   (2067, 16),
#   (2069, 4),
#   (2072, 3),
#   (2086, 1),
#   (2095, 1),
#   (2215, 1),
#   (2216, 1),
#   (2362, 2),
#   (2370, 1),
#   (2374, 3),
#   (2451, 1),
#   (2457, 1),
#   (2458, 1),
#   (2478, 1),
#   (2532, 1),
#   (2572, 3),
#   (2590, 1),
#   (2640, 1),
#   (2751, 1),
#   (2768, 3),
#   (2800, 1),
#   (2850, 1),
#   (2871, 1),
#   (2882, 1),
#   (2957, 4),
#   (2960, 6),
#   (2975, 1),
#   (2976, 1),
#   (2979, 1),
#   (2984, 3),
#   (2988, 2),
#   (2989, 1),
#   (2996, 1),
#   (3019, 1),
#   (3033, 1),
#   (3034, 1),
#   (3035, 1),
#   (3036, 1),
#   (3037, 1),
#   (3038, 1),
#   (3039, 2),
#   (3040, 2),
#   (3041, 1),
#   (3042, 1),
#   (3043, 2),
#   (3044, 1),
#   (3045, 1),
#   (3046, 1),
#   (3047, 1),
#   (3048, 1)],
#  [(3, 1),
#   (17, 1),
#   (19, 1),
#   (22, 2),
#   (24, 1),
#   (25, 1),
#   (27, 8),
#   (34, 1),
#   (58, 3),
#   (71, 1),
#   (74, 1),
#   (81, 1),
#   (87, 1),
#   (95, 1),
#   (110, 1),
#   (133, 1),
#   (160, 1),
#   (163, 2),
#   (167, 4),
#   (184, 1),
#   (202, 2),
#   (210, 1),
#   (213, 1),
#   (229, 1),
#   (232, 1),
#   (247, 4),
#   (267, 2),
#   (269, 2),
#   (290, 1),
#   (302, 1),
#   (305, 1),
#   (355, 6),
#   (356, 3),
#   (359, 1),
#   (360, 1),
#   (473, 3),
#   (474, 4),
#   (515, 1),
#   (568, 1),
#   (605, 1),
#   (619, 1),
#   (646, 1),
#   (664, 11),
#   (679, 5),
#   (685, 1),
#   (692, 1),
#   (704, 3),
#   (710, 1),
#   (737, 1),
#   (743, 4),
#   (826, 1),
#   (851, 1),
#   (873, 1),
#   (875, 1),
#   (976, 3),
#   (1025, 18),
#   (1057, 1),
#   (1101, 1),
#   (1102, 1),
#   (1142, 1),
#   (1222, 1),
#   (1268, 4),
#   (1357, 1),
#   (1402, 1),
#   (1491, 1),
#   (1529, 1),
#   (1531, 1),
#   (1563, 1),
#   (1616, 1),
#   (1912, 1),
#   (1938, 3),
#   (1998, 1),
#   (2064, 1),
#   (2432, 3),
#   (2466, 1),
#   (2538, 8),
#   (2557, 4),
#   (2756, 2),
#   (2813, 1),
#   (2820, 1),
#   (2850, 1),
#   (2937, 3),
#   (3030, 1),
#   (3049, 1),
#   (3050, 1),
#   (3051, 1),
#   (3052, 1),
#   (3053, 5),
#   (3054, 4),
#   (3055, 1),
#   (3056, 1),
#   (3057, 1),
#   (3058, 1),
#   (3059, 1),
#   (3060, 1),
#   (3061, 2),
#   (3062, 1),
#   (3063, 3),
#   (3064, 1),
#   (3065, 1)],
#  [(3, 1),
#   (27, 4),
#   (30, 2),
#   (34, 1),
#   (87, 1),
#   (88, 1),
#   (108, 1),
#   (158, 1),
#   (163, 1),
#   (230, 6),
#   (247, 11),
#   (251, 1),
#   (268, 2),
#   (298, 1),
#   (305, 2),
#   (329, 1),
#   (414, 1),
#   (446, 1),
#   (476, 1),
#   (619, 1),
#   (646, 1),
#   (659, 3),
#   (667, 1),
#   (702, 1),
#   (704, 1),
#   (892, 1),
#   (953, 2),
#   (966, 1),
#   (1010, 1),
#   (1025, 11),
#   (1072, 1),
#   (1247, 6),
#   (1763, 1),
#   (1903, 1),
#   (1949, 2),
#   (2072, 1),
#   (2129, 1),
#   (2488, 1),
#   (2529, 2),
#   (2624, 1),
#   (2627, 1),
#   (2671, 1),
#   (2679, 1),
#   (2793, 1),
#   (2892, 2),
#   (2893, 7),
#   (2895, 1),
#   (2896, 3),
#   (2898, 1),
#   (2899, 1),
#   (2901, 1),
#   (2902, 1),
#   (2911, 1),
#   (2979, 1),
#   (3003, 2),
#   (3066, 3),
#   (3067, 1),
#   (3068, 1),
#   (3069, 1),
#   (3070, 1),
#   (3071, 1),
#   (3072, 1),
#   (3073, 4),
#   (3074, 1),
#   (3075, 2)]]

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=my_num_topic, id2word = dictionary, passes=10)

# %%
# 추출된 토픽과 토픽에 포함된 키워드를 저장할 리스트를 생성합니다.
topic_list = []

# 추출된 토픽을 리스트에 저장합니다.
for num in range(my_num_topic):
    topic_list.append(ldamodel.show_topic(num, my_num_keyword ))

# %%
topic_list
# Out:
# [[('금융', 0.049120657),
#   ('부동산', 0.040160567),
#   ('금리', 0.03879723),
#   ('대출', 0.02443075),
#   ('은행', 0.019721512),
#   ('기준', 0.01438058),
#   ('신탁', 0.010352521),
#   ('그림자', 0.010344678),
#   ('투자', 0.009007518),
#   ('시장', 0.008533445)],
#  [('비트', 0.058801472),
#   ('화폐', 0.021032779),
#   ('암호', 0.016877422),
#   ('거래', 0.011786559),
#   ('달러', 0.010319084),
#   ('블록', 0.009131999),
#   ('금융', 0.009086059),
#   ('체인', 0.009041243),
#   ('인은', 0.008496547),
#   ('시장', 0.0080155255)],
#  [('금리', 0.054119274),
#   ('대출', 0.034668516),
#   ('금융', 0.029693052),
#   ('은행', 0.01842516),
#   ('자산', 0.0149236275),
#   ('평균', 0.012236343),
#   ('기준', 0.012183159),
#   ('최고', 0.011683498),
#   ('신용', 0.009768595),
#   ('디지털', 0.009691073)]]

# %%
# 추출된 토픽을 출력합니다.
for index in range(len(topic_list)):
    print("# 주제", index + 1)
    for topic in topic_list[index]:
        print("\t", topic[0].split("/")[0])
# Out:
# # 주제 1
# 	 금융
# 	 부동산
# 	 금리
# 	 대출
# 	 은행
# 	 기준
# 	 신탁
# 	 그림자
# 	 투자
# 	 시장
# # 주제 2
# 	 비트
# 	 화폐
# 	 암호
# 	 거래
# 	 달러
# 	 블록
# 	 금융
# 	 체인
# 	 인은
# 	 시장
# # 주제 3
# 	 금리
# 	 대출
# 	 금융
# 	 은행
# 	 자산
# 	 평균
# 	 기준
# 	 최고
# 	 신용
# 	 디지털

# %% [markdown]
# #### 1.4. LDA토픽모델링 결과 시각화하기
#
# ---

# %%
# LDA토픽모델링 결과를 시각화하는 pyLDAvis 패키지를 설치합니다.

# !pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting numpy>=1.24.2 (from pyLDAvis)
#   Using cached numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: scipy in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.11.3)
# Requirement already satisfied: pandas>=2.0.0 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: jinja2 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (3.1.3)
# Requirement already satisfied: numexpr in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (2.8.3)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: gensim in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: setuptools in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (69.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0.0->pyLDAvis) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.1.0)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/ijiseon/opt/anaconda3/lib/python3.9/site-packages (from packaging->numexpr->pyLDAvis) (3.0.9)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 4.6 MB/s eta 0:00:0000:0100:01
# Using cached numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Installing collected packages: funcy, numpy, pyLDAvis
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# islp 0.3.21 requires numpy<1.25,>=1.7.1, but you have numpy 1.26.4 which is incompatible.
# islp 0.3.21 requires pandas<=1.9,>=0.20, but you have pandas 2.2.2 which is incompatible.
# pytorch-lightning 2.1.0 requires torch>=1.12.0, but you have torch 1.10.1 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.26.4 which is incompatible.
# torchvision 0.15.2 requires torch==2.0.1, but you have torch 1.10.1 which is incompatible.
# ydata-synthetic 1.3.2 requires numpy==1.23.*, but you have numpy 1.26.4 which is incompatible.
# ydata-synthetic 1.3.2 requires pandas==2.0.*, but you have pandas 2.2.2 which is incompatible.
# Successfully installed funcy-2.0 numpy-1.26.4 pyLDAvis-3.4.1

# %%
# pyLDAvis 패키지를 불러옵니다.
import pyLDAvis.gensim

# LDA토픽모델링 시각화 결과를 출력합니다.
pyLDAvis.enable_notebook()
lda_display = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary, sort_topics=True)
pyLDAvis.display(lda_display)

# Intertopic Distance Map의 각 주제가 겹치지 않고 잘 구분되면 적절한 토픽개수라고 볼 수 있습니다.
# 그래프의 분포를 확인하며 토픽의 개수를 조정합니다.
# LDA토픽모델링은 분석 수행시마다 매번 결과가 달라집니다.
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el747631406129226486087109176336" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el747631406129226486087109176336_data = {"mdsDat": {"x": [-0.13952357064659765, 0.18403769359881775, -0.04451412295222003], "y": [-0.0781399235917082, -0.03248292267093498, 0.11062284626264325], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [48.81295087090457, 32.835373690811686, 18.35167543828374]}, "tinfo": {"Term": ["\uae08\ub9ac", "\ube44\ud2b8", "\ubd80\ub3d9\uc0b0", "\ub300\ucd9c", "\ud654\ud3d0", "\uc554\ud638", "\uae08\uc735", "\uc740\ud589", "\ud3c9\uade0", "\ub2ec\ub7ec", "\ucd5c\uace0", "\uc2e0\ud0c1", "\uadf8\ub9bc\uc790", "\uc790\uc0b0", "\uac70\ub798", "\uae30\uc900", "\uc774\ud558", "\uc2e0\uc6a9", "\uc778\uc740", "\ub514\uc9c0\ud138", "\ube14\ub85d", "\ubbf8\ub9cc", "\ub9ac\uc2a4\ud06c", "\uccb4\uc778", "\uac00\uaca9", "\uc0b0\uc815", "\uc794\uc561", "\uac00\uc0b0", "\uc778\ud558", "\uc778\uc758", "\uc2e0\ud0c1", "\ubd80\ub3d9\uc0b0", "\uadf8\ub9bc\uc790", "\uac00\uc0b0", "\uc0b0\uc815", "\ub9ac\uc2a4\ud06c", "\ubc29\uc548", "\uc0c1\ud658", "\uc911\ub3c4", "\uc218\uc218\ub8cc", "\ub9ac\uc2a4", "\uc9c0\uc8fc", "\uacbd\uae30", "\uad50\uc721", "\uc2e0\ud0c1\uc5c5", "\uc810\uac80", "\uc120\uc784", "\ucd94\uc0b0", "\uc794\uc561", "\uc720\ub3d9\ud654", "\uc608\ube44", "\ucc28\uc6d0", "\ud658\ub9e4", "\uad50\uc721\uc6d0", "\uc694\uad6c\ubd88", "\ubcf4\uac15", "\uc784\ub300", "\uc5f0\uad6c\uc6d0", "\uc5f0\ud569\ud68c", "\uc5c5\ubb34", "\uc99d\uad8c\uc0ac", "\uc608\uae08", "\uc870\ub2ec", "\uc2e0\uaddc", "\uaddc\ubaa8", "\uc790\uae08", "\uae08\uc735", "\uad00\uacc4\uc790", "\uacbd\uc6b0", "\uae08\ub9ac", "\uad00\ub828", "\uae30\uc900", "\ud3ec\uc778\ud2b8", "\uc740\ud589", "\ub300\ucd9c", "\ubcc0\ub3d9", "\ub2f9\uad6d", "\uad00\ub9ac", "\ud22c\uc790", "\uc778\ud558", "\uc0c1\ud488", "\uc2dc\uc7a5", "\uae30\uc790", "\ud380\ub4dc", "\uad6d\ub0b4", "\uc2e0\uc6a9", "\uae30\uc874", "\uc790\uc0b0", "\ub2ec\ub7ec", "\uc554\ud638", "\uc778\uc758", "\ud654\ud3d0", "\uc2dc\uc138", "\uc778\uc740", "\uc720\ub300\uc778", "\ucd5c\ucd08", "\uc778\ud130\ubdf0", "\ud53c\uc790", "\ub3c5\uc7ac", "\uc9c8\uc11c", "\ub9c8\uc57d", "\ucc44\uad74", "\uc0ac\uc774\ud2b8", "\uc624\uc804", "\ubc1c\ud589", "\uad50\uc218", "\ub9ac\ud50c", "\ucd1d\uad04", "\uc8fc\ub958", "\uac1c\ubc1c\uc790", "\uc0ac\uac74", "\ud68c\uc7a5", "\uc2dc\uac04", "\uc804\uc1a1", "\uc5d8\ub9ac\ud2b8", "\ud558\uc774", "\uc131\uc804", "\uc18c\uc218", "\ube44\ud2b8", "\uac70\ub798\uc18c", "\ube14\ub85d", "\uc554\ud638\ud654", "\uac00\uaca9", "\uac70\ub798", "\uccb4\uc778", "\ud604\uc9c0", "\uc790\uc2e0", "\ubbf8\uad6d", "\ud22c\uc790\uc790", "\uc218\ub2e8", "\uc0c1\uc2b9", "\uac00\uce58", "\uc2dc\uc791", "\uc138\uacc4", "\uc2b9\uc778", "\ub2f7\ucef4", "\uae30\uc220", "\uc815\ubd80", "\uac00\uc0c1", "\uacbd\uc81c", "\uc2dc\uc7a5", "\uc11c\ube44\uc2a4", "\ud22c\uc790", "\uae08\uc735", "\uc790\uc0b0", "\uae30\uc790", "\uc740\ud589", "\uc2a4\ud0c0", "\uce74\ub4dc\uc0ac", "\uace0\uae08\ub9ac", "\ub4f1\ud654", "\uc608\uce58\uae08", "\uad6c\uc5ed", "\uc778\ud504\ub77c", "\uc774\ud558", "\ub300\ucd9c\uc561", "\uacbd\uc81c\uc801", "\ubbf8\ub9cc", "\uc8fc\ub2f4", "\uc0ac\uae08\uc735", "\ud30c\ud2b8", "\ud558\ud5a5", "\ub4f1\uae09", "\ubd09\ucc29", "\ucee4\ud53c", "\ub9ac\uc11c\uce58", "\ucda9\ub2f9\uae08", "\ud0dd\uc2dc", "\uc5ed\uc804", "\uc13c\ud130", "\ucd5c\uace0", "\uc560\ud50c", "\uce90\ud53c\ud138", "\uc0c1\uc774", "\ud2b9\ud654", "\uac00\uc9c0", "\ud2f0\ub098", "\ud611\uc5c5", "\uc0c1\ud638", "\ud30c\ud2b8\ub108", "\uce74\ub4dc", "\ub9cc\uc0ad", "\ud14c\ud06c", "\ud3c9\uade0", "\uace8\ub4dc", "\ub514\uc9c0\ud138", "\ubc95\ub960", "\uc800\ucd95", "\uac01\uc885", "\uae08\ub9ac", "\ub300\ucd9c", "\uc790\uc0b0", "\uc5ec\uc2e0", "\uc2e0\uc6a9", "\uae30\uc5c5", "\uc740\ud589", "\uae08\uc735", "\uae30\uc900", "\uae00\ub85c\ubc8c", "\ud1b5\ud654", "\ub2f9\uad6d", "\uc778\uc815", "\uace0\uc815", "\uc778\ud558", "\ube44\ud2b8", "\uaddc\uc81c", "\uae30\uc790", "\uc11c\ube44\uc2a4", "\ubcf4\uace0\uc11c"], "Freq": [692.0, 499.0, 472.0, 438.0, 168.0, 135.0, 776.0, 338.0, 76.0, 8 ...

# %% [markdown]
# ### 2. 감성분석: 문장의 감성수준을 수치로 표현하기
#
# ---

# %% [markdown]
# #### 2.1. 샘플 데이터 불러오기
#
# ---

# %%
# 영화리뷰을 저장할 리스트를 생성합니다.
review_list = []

# 본 자료에서 제공하는 리뷰는 2019년 개봉작 "엑스맨: 다크 피닉스"의 리뷰입니다.
file_path = "/Users/ijiseon/Desktop/ESAA-OB/review_sample.txt"

# 리뷰가 저장된 파일을 불러옵니다.
f = open(file_path, encoding="utf-8")
for line in f:
    review_text = line.strip()
    review_list.append(review_text)
f.close()

print("총 리뷰 수 :", len(review_list))
# Out:
# 총 리뷰 수 : 1000

# %%
print("리뷰샘플 :")
print(review_list[10])
# Out:
# 리뷰샘플 :
# 이게 마지막이라고?? 정말?? 이렇게 끝낸다고??

# %% [markdown]
# #### 2.2. 리뷰 문장을 형태소 단위로 분리하기
#
# ---

# %%
# 꼬꼬마 형태소 분석기를 불러옵니다.
from konlpy.tag import Kkma
kkma = Kkma()

text = "꼬꼬마 형태소 분석기를 불러옵니다."
print(kkma.pos(text))
# Out:
# [('꼬꼬마', 'NNG'), ('형태소', 'NNG'), ('분석기', 'NNG'), ('를', 'JKO'), ('불러오', 'VV'), ('ㅂ니다', 'EFN'), ('.', 'SF')]

# %%
# 형태소분석 후 기사단위의 형태소 리스트를 저장할 리스트를 생성합니다.
tag_sentence_list = []

# 불용어를 리스트를 정의합니다.
stop_list = ["카페", "카페규정"]

now = 0
for review in review_list:
    now += 1
    print(now, end="\r")
    tag_list = kkma.pos(review)
    tag_sentence = []
    for word, pos in tag_list:
        tag_sentence.append(word + "/" + pos)
    tag_sentence_list.append(tag_sentence)
# Out:
# 1000

# %%
print("리뷰 형태소분석 샘플 :")
print("- 원문 :", review_list[10])
print("- 결과 :", tag_sentence_list[10])
# Out:
# 리뷰 형태소분석 샘플 :
# - 원문 : 이게 마지막이라고?? 정말?? 이렇게 끝낸다고??
# - 결과 : ['이것/NP', '이/JKS', '마지막/NNG', '이/VCP', '라고/ECD', '??/SW', '정말/MAG', '??/SW', '이렇/VA', '게/ECD', '끝내/VV', 'ㄴ다고/ECE', '??/SW']

# %% [markdown]
# #### 2.3. 감성사전 불러오기
#
# ---

# %%
# 본 자료에서는 KOSAC(Korean Sentiment Analysis Corpus)이라는 공개 감성사전을 활용합니다.
# 감성사전은 아래 링크에서 다운로드 가능합니다.
# 다운로드한 파일 준 polarity.csv 파일을 활용합니다.

# %% [markdown]
# 감성사전 다운로드 URL : http://word.snu.ac.kr/kosac/lexicon.php

# %%
# KOSAC 감성사전의 내용을 살펴봅니다.
f = open("/Users/ijiseon/Desktop/ESAA-OB/polarity.csv", encoding="utf-8")
for line in f.read().split("\n")[:10]:
    line = line.strip().split(",")
    print(line)
f.close()
# Out:
# ['ngram', 'freq', 'COMP', 'NEG', 'NEUT', 'None', 'POS', 'max.value', 'max.prop']
# ['가*/JKS', '1', '0', '0', '0', '0', '1', 'POS', '1']
# ['가*/JKS;있/VV', '1', '0', '0', '0', '0', '1', 'POS', '1']
# ['가*/JKS;있/VV;었/EP', '1', '0', '0', '0', '0', '1', 'POS', '1']
# ['가*/VV', '3', '0', '0', '0', '0', '1', 'POS', '1']
# ['가*/VV;ㄴ다*/EF', '1', '0', '0', '0', '0', '1', 'POS', '1']
# ['가/JKC', '17', '0', '0.470588235', '0.235294118', '0', '0.294117647', 'NEG', '0.470588235']
# ['가/JKC;되/VV', '11', '0', '0.363636364', '0.272727273', '0', '0.363636364', 'NEG', '0.363636364']
# ['가/JKC;되/VV;ㄴ/ETM', '2', '0', '0', '1', '0', '0', 'NEUT', '1']
# ['가/JKC;되/VV;ㄹ/ETM', '1', '0', '0', '1', '0', '0', 'NEUT', '1']

# %%
# KOSAC 감성사전을 불러와 딕셔너리에 저장합니다.
# 원본 사전에 세미콜론(;)으로 구분된 형태소를 띄어쓰기 단위로 변형하여 딕셔너리의 키(key)값으로 활용합니다.

# 사전을 저장할 딕셔너리를 생성합니다.
sentiment = {}

f = open("/Users/ijiseon/Desktop/ESAA-OB/polarity.csv", encoding="utf-8")
for line in f:
    col = line.strip().split(",")
    pos = col[0]
    polarity = col[7]
    score = col[8]
    # 극성이 POS인 경우 +, NEG인 경우 -를 곱해 스코어(score)를 계산합니다.
    if polarity == "POS":
        score = float(score)
    elif polarity == "NEG":
        score = -float(score)
    else:
        # 긍정 또는 부정인 경우만 취급합니다.
        continue
    # 세미콜론(;)을 띄어쓰기로 바꿔 딕셔너리에 스코어와 함께 저장합니다.
    sentiment[pos.replace(";", " ")] = score

f.close()

# %%
# 생성한 감성사전 딕셔너리 샘플을 출력합니다.

# 긍정
print("(긍정) 솜씨/NNG 는/JX 능숙/XR :", sentiment["솜씨/NNG 는/JX 능숙/XR"])
print("(긍정) 자연/NNG 스럽/XSA :", sentiment["자연/NNG 스럽/XSA"])
print("(긍정) 획일/XR 성/XSN 의/JKG :", sentiment["획일/XR 성/XSN 의/JKG"])
print("(긍정) 훨씬/MAG 안전/NNG :", sentiment["훨씬/MAG 안전/NNG"])
# 부정
print("(부정) 뒷맛/NNG 이/JKS 씁쓸/XR :", sentiment["뒷맛/NNG 이/JKS 씁쓸/XR"])
print("(부정) 손해/NNG 배상/NNG 을/JKO :", sentiment["손해/NNG 배상/NNG 을/JKO"])
print("(부정) 에서/JKB 욕/NNG 튀어나오/VV :", sentiment["에서/JKB 욕/NNG 튀어나오/VV"])
print("(부정) 유달리/MAG 난해/XR :", sentiment["유달리/MAG 난해/XR"])
# Out:
# (긍정) 솜씨/NNG 는/JX 능숙/XR : 1.0
# (긍정) 자연/NNG 스럽/XSA : 1.0
# (긍정) 획일/XR 성/XSN 의/JKG : 1.0
# (긍정) 훨씬/MAG 안전/NNG : 1.0
# (부정) 뒷맛/NNG 이/JKS 씁쓸/XR : -1.0
# (부정) 손해/NNG 배상/NNG 을/JKO : -1.0
# (부정) 에서/JKB 욕/NNG 튀어나오/VV : -1.0
# (부정) 유달리/MAG 난해/XR : -1.0

# %% [markdown]
# #### 2.4. 리뷰 감성스코어 계산하기
#
# ---

# %%
# 감성분석 결과를 긍정과 부정 리뷰로 각각 저장할 리스트를 생성합니다.
positive_sentence = []
negative_sentence = []

for tag_sentence, review in zip(tag_sentence_list, review_list):
    # 스코어를 0점으로 초기화합니다.
    score = 0.0
    # 형태소분석된 문장 안에서 최대 7개까지 결합된 형태소가 감성사전 안에 있는지 확인합니다.
    for i in range(len(tag_sentence)):
        max_n = 7
        for n in range(max_n):
            ngram = ""
            for j in range(len(tag_sentence)-n):
                ngram += " " + tag_sentence[j]
            ngram = ngram.strip()
            if ngram in sentiment.keys():
                score += sentiment[ngram]
    # 감성스코어로 긍정 또는 부정을 판단하기위한 임계값을 지정합니다.
    limit = 0
    if score > limit:
        positive_sentence.append(["POSITIVE", str(review)])
    elif score < -limit:
        negative_sentence.append(["NEGATIVE", str(review)])

# 감성분석 결과를 감성스코어를 기준으로 정렬합니다.
positive_sentence.sort(reverse=True)
negative_sentence.sort()

# %% [markdown]
# #### 2.5. 리뷰 감성분석 결과 확인하기
# - 본 자료에서 사용하는 KOSAC 감성사전은 표준어를 바탕으로 제작되었습니다.
# - 온라인 리뷰의 특성상 문법의 오류가 굉장히 많기 때문에 사전과의 매칭률이 낮을 수 있습니다.
# - 또한 KOSAC 감성사전의 형태소태깅과 본 자료에서 사용한 꼬꼬마 형태소분석기의 형태소태깅 결과의 차이도 영향을 미칩니다.
# - 본 자료의 결과가 모두 맞는 것은 아니며 사전기반의 감성분석을 수행하는 방법에 대한 이해를 위해 사용해주세요.
# - 직접 분석하려는 텍스트의 도메인에 맞는 사전을 추가하여 정확도를 높힐 수 있습니다.
#
# ---

# %%
print("긍정판별 문장 개수 :", len(positive_sentence))
positive_sentence[:10]
# Out:
# 긍정판별 문장 개수 : 27
# [['POSITIVE', '흥미진진 마지막액션씬최고'],
#  ['POSITIVE', '하루빨리 통합마블 되기를'],
#  ['POSITIVE', '최고최고최고최고최고!'],
#  ['POSITIVE', '최고ㅜㅜ 레이븐ㅠㅠㅠ'],
#  ['POSITIVE', '장난합니까 마지막 영환데'],
#  ['POSITIVE', '은혜를 모르는 진 그레이..'],
#  ['POSITIVE', '영화보는데 기빨린다 후하'],
#  ['POSITIVE', '영화를 만들다 말았어...'],
#  ['POSITIVE', '아주 재밌습니다 후회없음'],
#  ['POSITIVE', '생각보다 많이 괜찮은 영화']]

# %%
print("부정판별 문장 개수 :", len(negative_sentence))
negative_sentence[:10]
# Out:
# 부정판별 문장 개수 : 13
# [['NEGATIVE', '계속 생각 나는 영화. ㅠㅠ'],
#  ['NEGATIVE', '그냥 개똥보다 못한 영화'],
#  ['NEGATIVE', '난재밌었어요....'],
#  ['NEGATIVE', '내 개인 평점 7.2..;;'],
#  ['NEGATIVE', '말이 필요없습니다. 재미있어요'],
#  ['NEGATIVE', '스토리 너무 늘어지는듯'],
#  ['NEGATIVE', '스토리가 왜이리 이상하냐'],
#  ['NEGATIVE', '아쉬움가득안고떠납니다'],
#  ['NEGATIVE', '아쉽지만 행복했습니다'],
#  ['NEGATIVE', '왜 엑스우먼이 아닌지ㅎ']]
